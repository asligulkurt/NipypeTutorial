# %%
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Preprocessing Workflow
#
# This is meant as a very simple example for a preprocessing workflow. In this workflow we will conduct the following steps:
#
# So let's get our hands dirty. First things first, it's always good to know which interfaces you want to use in your workflow and in which order you want to execute them. For the preprocessing workflow, I recommend that we use the following nodes:
#
#      1. Gunzip (Nipype) (not applied)
#      2. Drop Dummy Scans (FSL) (not applied)
#      3. Slice Time Correction (SPM) (not applied)
#      4. Motion Correction (FSL)
#      5. Artifact Detection (not applied)
#      6. Segmentation (SPM)
#      7. Coregistration (FSL)
#      8. Smoothing (FSL)
#      9. Apply Binary Mask (FSL)
#     10. Remove Linear Trends (Nipype)
#
# **Note:** This workflow might be overkill concerning data manipulation, but it hopefully serves as a good Nipype exercise.

# %% [markdown]
# ## Imports
#
# First, let's import all modules we later will be needing.

# %%
from os.path import join as opj
import os
import json
import nipype.interfaces.fsl as fsl
from nipype.interfaces.fsl import MCFLIRT, FLIRT
from nipype.interfaces.spm import Smooth
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
from nipype.interfaces.spm import NewSegment
from nipype.interfaces.fsl import FLIRT
from nipype.interfaces.fsl import Threshold
from nipype.algorithms.confounds import TSNR
from nipype.interfaces.fsl import ApplyMask
from nipype.algorithms.misc import Gunzip
from nipype import MapNode

# %% [markdown]
# # Dicom to Nifti conversion

# %%
from nipype.interfaces.dcm2nii import Dcm2nii
converter = Dcm2nii()

# convert anatomical data
converter.inputs.gzip_output = False
converter.inputs.source_dir = './data/sub-01/anat/T1_dcm'
converter.inputs.output_dir = './data/sub-01/anat/'
converter.inputs.protocol_in_filename = False
converter.inputs.source_in_filename = False
converter.inputs.date_in_filename = False
converter.inputs.events_in_filename = False
converter.inputs.id_in_filename = True 
converter.inputs.reorient = False
converter.run()
# Out:
# 181204-04:29:33,147 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181204-04:29:33,149 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:reading preferences file config.ini
# 181204-04:29:33,151 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:Data will be exported to ./data/sub-01/anat/
# 181204-04:29:33,152 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:Validating 176 potential DICOM images.
# 181204-04:29:33,154 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:Found 176 DICOM images.
# 181204-04:29:33,155 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.146944:Converting 176/176  volumes: 1
# 181204-04:29:33,196 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.196532:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0002.0001.2018.11.27.10.49.46.171875.342669378.IMA->psych521visualMotor.nii
# 181204-04:29:33,198 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.196532:For slice timing correction: the slice order is ascending
# 181204-04:29:33,201 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.196532: brightest voxel was 908: data will be saved as 16-bit signed integer.
# 181204-04:29:33,221 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:33.221141:Saving ./data/sub-01/anat/psych521visualMotor.nii

# %%
# rename the ziped file according to your convention
new_file_name = './data/sub-01/anat/sub-01_T1.nii'
old_file_name = './data/sub-01/anat/psych521visualMotor.nii'
os.rename(old_file_name, new_file_name)

# %%
# %matplotlib inline
from nilearn import plotting

filename = './data/sub-01/anat/sub-01_T1.nii'

plotting.plot_anat(filename,
                   display_mode='z',
                   cut_coords = (10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60),
                   title="plot_anat")

# %%
# convert functional runs data
run_list = ['run-01', 'run-02', 'run-03', 'run-04']
for run in run_list:
    converter = Dcm2nii()
    converter.inputs.gzip_output = False
    converter.inputs.source_dir = './data/sub-01/func/'+run+'_bold_dcm'
    converter.inputs.output_dir = './data/sub-01/func/'
    converter.inputs.protocol_in_filename = False
    converter.inputs.source_in_filename = False
    converter.inputs.date_in_filename = False
    converter.inputs.events_in_filename = False
    converter.inputs.id_in_filename = True 
    converter.run() 
    # rename the ziped file according to your convention
    new_file_name = './data/sub-01/func/sub-01_'+run+'_bold.nii'
    old_file_name = './data/sub-01/func/psych521visualMotor.nii'
    os.rename(old_file_name, new_file_name)
# Out:
# 181204-04:29:40,479 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181204-04:29:40,481 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:reading preferences file config.ini
# 181204-04:29:40,482 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:Data will be exported to ./data/sub-01/func/
# 181204-04:29:40,484 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:Validating 135 potential DICOM images.
# 181204-04:29:40,485 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:Found 135 DICOM images.
# 181204-04:29:40,490 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.479229:Converting 135/135  volumes: 135
# 181204-04:29:40,491 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.491920:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0003.0001.2018.11.27.10.49.46.171875.342673476.IMA->psych521visualMotor.nii
# 181204-04:29:40,493 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.491920: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181204-04:29:40,494 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.491920:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	1002.5	0	1070	65	1137.5	132.5	1202.5	200	1270	267.5	1337.5	335	1405	400	1472.5	467.5	1537.5	535	1605	602.5	1672.5	667.5	1740	735	1805	802.5	1872.5	870	1940	935
# 181204-04:29:40,676 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.676336:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181204-04:29:40,677 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.676336:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181204-04:29:40,679 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.676336: brightest voxel was 1252: data will be saved as 16-bit signed integer.
# 181204-04:29:40,710 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.710106:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181204-04:29:40,926 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181204-04:29:40,928 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:reading preferences file config.ini
# 181204-04:29:40,931 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:Data will be exported to ./data/sub-01/func/
# 181204-04:29:40,934 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:Validating 135 potential DICOM images.
# 181204-04:29:40,935 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:Found 135 DICOM images.
# 181204-04:29:40,937 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.926033:Converting 135/135  volumes: 135
# 181204-04:29:40,939 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.939120:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0005.0001.2018.11.27.10.49.46.171875.342678598.IMA->psych521visualMotor.nii
# 181204-04:29:40,940 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.939120: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181204-04:29:40,942 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:40.939120:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	1005	0	1070	67.5	1137.5	135	1205	202.5	1272.5	267.5	1340	335	1405	402.5	1472.5	470	1540	535	1607.5	602.5	1672.5	670	1740	737.5	1807.5	802.5	1875	870	1940	937.5
# 181204-04:29:41,114 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.114590:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181204-04:29:41,115 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.114590:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181204-04:29:41,116 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.114590: brightest voxel was 1290: data will be saved as 16-bit signed integer.
# 181204-04:29:41,145 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.145457:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181204-04:29:41,390 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181204-04:29:41,391 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:reading preferences file config.ini
# 181204-04:29:41,393 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:Data will be exported to ./data/sub-01/func/
# 181204-04:29:41,394 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:Validating 135 potential DICOM images.
# 181204-04:29:41,395 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:Found 135 DICOM images.
# 181204-04:29:41,401 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.390349:Converting 135/135  volumes: 135
# 181204-04:29:41,403 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.403517:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0007.0001.2018.11.27.10.49.46.171875.342683720.IMA->psych521visualMotor.nii
# 181204-04:29:41,405 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.403517: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181204-04:29:41,406 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.403517:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	1002.5	0	1070	67.5	1137.5	132.5	1205	200	1270	267.5	1337.5	335	1405	400	1472.5	467.5	1537.5	535	1605	602.5	1672.5	667.5	1740	735	1805	802.5	1872.5	870	1940	935
# 181204-04:29:41,589 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.589663:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181204-04:29:41,590 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.589663:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181204-04:29:41,592 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.589663: brightest voxel was 1337: data will be saved as 16-bit signed integer.
# 181204-04:29:41,623 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.623671:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181204-04:29:41,830 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181204-04:29:41,832 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:reading preferences file config.ini
# 181204-04:29:41,833 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:Data will be exported to ./data/sub-01/func/
# 181204-04:29:41,837 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:Validating 135 potential DICOM images.
# 181204-04:29:41,839 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:Found 135 DICOM images.
# 181204-04:29:41,841 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.830049:Converting 135/135  volumes: 135
# 181204-04:29:41,844 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.844230:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0009.0001.2018.11.27.10.49.46.171875.342688842.IMA->psych521visualMotor.nii
# 181204-04:29:41,845 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.844230: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181204-04:29:41,846 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:41.844230:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	1005	0	1070	67.5	1137.5	135	1205	200	1272.5	267.5	1337.5	335	1405	402.5	1472.5	467.5	1540	535	1605	602.5	1672.5	670	1740	735	1807.5	802.5	1872.5	870	1940	937.5
# 181204-04:29:42,22 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:42.022799:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181204-04:29:42,23 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:42.022799:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181204-04:29:42,24 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:42.022799: brightest voxel was 1337: data will be saved as 16-bit signed integer.
# 181204-04:29:42,53 nipype.interface INFO:
# 	 stdout 2018-12-04T04:29:42.053780:Saving ./data/sub-01/func/psych521visualMotor.nii

# %%
# %matplotlib inline
from nilearn import image
from nilearn import plotting

filename = './data/sub-01/func/sub-01_run-01_bold.nii'
print(image.load_img(filename).shape)

selected_volume = image.index_img(filename, 0)

count = 0
for img in image.iter_img(filename):
    # img is now an in-memory 3D img
    
    if count%40==0:
        plotting.plot_anat(img,
                           display_mode='z',
                           cut_coords = (10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60),
                           title="volume %d"%count)
    count += 1
# Out:
# (64, 64, 30, 135)

# %% [markdown]
# # Experiment parameters
#
# It's always a good idea to specify all parameters that might change between experiments at the beginning of your script.

# %%
data_dir = '/home/neuro/nipype_tutorial/data/'

experiment_dir = '/home/neuro/nipype_tutorial/output/'
output_dir = '/home/neuro/nipype_tutorial/output/datasink'
working_dir = '/home/neuro/nipype_tutorial/output/workingdir'

# list of subject identifiers
subject_list = ['sub-01']


# list of run identifiers
run_list = ['run-01', 'run-02', 'run-03', 'run-04']


# TR of functional images
TR = 2.0

# Smoothing withds used during preprocessing
fwhm = [4, 8]

# %%
# Use the following tissue specification to get a GM and WM probability map
tpm_img ='/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii'
tissue1 = ((tpm_img, 1), 1, (True,False), (False, False))
tissue2 = ((tpm_img, 2), 1, (True,False), (False, False))
tissue3 = ((tpm_img, 3), 2, (True,False), (False, False))
tissue4 = ((tpm_img, 4), 3, (False,False), (False, False))
tissue5 = ((tpm_img, 5), 4, (False,False), (False, False))
tissue6 = ((tpm_img, 6), 2, (False,False), (False, False))
tissues = [tissue1, tissue2, tissue3, tissue4, tissue5, tissue6]

# %% [markdown]
# ## Specify Nodes for the main workflow
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# MCFLIRT - motion correction
mcflirt = Node(MCFLIRT(mean_vol=True,
                       save_plots=True,
                       output_type='NIFTI'),
               name="mcflirt")

segment = Node(NewSegment(tissues=tissues), name='segment')

# FLIRT - coregister functional images to anatomical images
coreg_step1 = Node(FLIRT(dof=6,
                   cost='bbr',
                   schedule='/usr/share/fsl/5.0/etc/flirtsch/bbr.sch',
                   output_type='NIFTI'),
             name="coreg")


# Threshold - Threshold WM probability image
threshold_WM = Node(Threshold(thresh=0.5,
                              args='-bin',
                              output_type='NIFTI'),
                name="threshold_WM")
# Specify the isometric voxel resolution you want after coregistration
desired_voxel_iso = 4

# Apply coregistration warp to functional images
coreg_step2 = Node(FLIRT(interp='spline',
                       apply_isoxfm=desired_voxel_iso,
                       output_type='NIFTI'),
                 name="applywarp")

# Initiate resample node
resample = Node(FLIRT(apply_isoxfm=desired_voxel_iso,
                      output_type='NIFTI'),
                name="resample")

# Threshold - Threshold GM probability image
mask_GM = Node(Threshold(thresh=0.5,
                         args='-bin -dilF',
                         output_type='NIFTI'),
                name="mask_GM")

# Smooth - image smoothing
smooth = Node(Smooth(), name="smooth")
smooth.iterables = ("fwhm", fwhm)


mask_func = MapNode(ApplyMask(output_type='NIFTI'),
                    name="mask_func", 
                    iterfield=["in_file"])

detrend = Node(TSNR(regress_poly=2), name="detrend")

# %% [markdown]
# ## Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'run_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('run_id', run_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
anat_file = opj('{subject_id}', 'anat', '{subject_id}_T1.nii')
func_file = opj('{subject_id}', 'func',
                '{subject_id}_{run_id}_bold.nii')

templates = {'anat': anat_file,
             'func': func_file}
selectfiles = Node(SelectFiles(templates,
                               base_directory=data_dir),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Create a preprocessing workflow
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Select WM segmentation file from segmentation output
def get_wm(files):
    return files[1][0]

def get_gm(files):
    return files[0][0]

# Connecting the segmentation node with the threshold node


# Connect all components of the preprocessing workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('run_id', 'run_id')]),
                 (selectfiles, mcflirt, [('func', 'in_file')]),
                 (selectfiles, segment, [('anat', 'channel_files')]),
                 (segment, threshold_WM, [(('native_class_images', get_wm), 'in_file')]),
                 (threshold_WM, coreg_step1, [('out_file', 'wm_seg')]),
                 
                 (mcflirt, coreg_step1, [('mean_img', 'in_file')]),
                 (selectfiles, coreg_step1, [('anat', 'reference')]),

                 (mcflirt, coreg_step2, [('out_file', 'in_file')]),
                 (selectfiles, coreg_step2, [('anat', 'reference')]),
                 (coreg_step1, coreg_step2, [('out_matrix_file',
                                              'in_matrix_file')]),

                 (segment, resample, [(('native_class_images', get_gm), 'in_file'),
                                      (('native_class_images', get_gm), 'reference')
                                      ]),
                 (resample, mask_GM, [('out_file', 'in_file')]),
                 
                 (coreg_step2, smooth, [('out_file', 'in_files')]),
                 (smooth, mask_func, [('smoothed_files', 'in_file')]),
                 (mask_GM, mask_func, [('out_file', 'mask_file')]),
                 (mask_func, detrend, [('out_file', 'in_file')]),

                 (mcflirt, datasink, [('par_file', 'preproc.@par')]),
                 (selectfiles, datasink, [('anat', 'preproc.@resample')]),
                 (coreg_step1, datasink, [('out_file', 'preproc.@coregmean')]),
                 (smooth, datasink, [('smoothed_files', 'preproc.@smooth')]),
                 (detrend, datasink, [('detrended_file', 'preproc.@detrend')]),
                 ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create preproc output graph
preproc.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(preproc.base_dir, 'preproc', 'graph.png'))
# Out:
# 181204-04:30:04,904 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/preproc/graph.png (graph2use=colored, simple_form=True).

# %%
# Visualize the detailed graph
preproc.write_graph(graph2use='flat', format='png', simple_form=True)
Image(filename=opj(preproc.base_dir, 'preproc', 'graph_detailed.png'))
# Out:
# 181204-04:30:05,628 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/preproc/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the preprocessing workflow. Change ``n_procs`` to the number of jobs/cores you want to use. **Note** that if  you're using a Docker container and FLIRT fails to run without any good reason, you might need to change memory settings in the Docker preferences (6 GB should be enough for this workflow).

# %%
preproc.run('MultiProc', plugin_args={'n_procs': 4})

# !nipypecli crash /home/neuro/nipype_tutorial/crash-20181202-135706-neuro-selectfiles.b0-54a99b2b-c1f7-47e5-bde8-8f401961f66f.pklz
# Out:
# 181204-04:30:05,921 nipype.workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging', 'monitoring']
# 181204-04:30:06,57 nipype.workflow INFO:
# 	 Running in parallel.
# 181204-04:30:06,111 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/numpy/matrixlib/defmatrix.py:68: PendingDeprecationWarning: the matrix subclass is not the recommended way to represent matrices or deal with linear algebra (see https://docs.scipy.org/doc/numpy/user/numpy-for-matlab-users.html). Please adjust your code to use regular ndarray.
#   return matrix(data, dtype=dtype, copy=False)
# 181204-04:30:06,240 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/selectfiles".181204-04:30:06,246 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/selectfiles".181204-04:30:06,243 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/selectfiles".
#
# 181204-04:30:06,248 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/selectfiles".
#
# 181204-04:30:06,288 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:30:06,262 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:30:06,290 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181204-04:30:06,303 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181204-04:30:06,322 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".181204-04:30:06,329 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 181204-04:30:06,323 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 181204-04:30:06,353 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
#
# 181204-04:30:08,91 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc.selectfiles).
# 181204-04:30:08,131 nipype.workflow INFO:
# 	 [Job 16] Completed (preproc.selectfiles).
# 181204-04:30:08,135 nipype.workflow INFO:
# 	 [Job 32] Completed (preproc.selectfiles).
# 181204-04:30:08,139 nipype.workflow INFO:
# 	 [Job 48] Completed (preproc.selectfiles).
# 181204-04:30:08,146 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:30:08,267 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.segment" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment".
# 181204-04:30:08,271 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mcflirt" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mcflirt".
# 181204-04:30:08,279 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.segment" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment".181204-04:30:08,285 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.spm.preprocess.NewSegment")181204-04:30:08,282 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mcflirt" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mcflirt".
# 181204-04:30:08,302 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/neuro/nipype_tutorial/data/sub-01/func/sub-01_run-04_bold.nii -meanvol -out /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mcflirt/sub-01_run-04_bold_mcf.nii -plots
#
# 181204-04:30:08,307 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.spm.preprocess.NewSegment")
#
# 181204-04:30:08,330 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/neuro/nipype_tutorial/data/sub-01/func/sub-01_run-03_bold.nii -meanvol -out /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mcflirt/sub-01_run-03_bold_mcf.nii -plots
# 181204-04:30:10,93 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.mcflirt
#                        * preproc.segment
#                        * preproc.mcflirt
#                        * preproc.segment
# 181204-04:31:03,694 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mcflirt".
# 181204-04:31:04,145 nipype.workflow INFO:
# 	 [Job 5] Completed (preproc.mcflirt).
# 181204-04:31:04,151 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 4 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.mcflirt
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:31:04,262 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.segment" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment".
# 181204-04:31:04,286 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.spm.preprocess.NewSegment")
# 181204-04:31:05,303 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mcflirt".
# 181204-04:31:06,151 nipype.workflow INFO:
# 	 [Job 21] Completed (preproc.mcflirt).
# 181204-04:31:06,156 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.segment
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:31:06,265 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mcflirt" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mcflirt".
# 181204-04:31:06,300 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/neuro/nipype_tutorial/data/sub-01/func/sub-01_run-02_bold.nii -meanvol -out /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mcflirt/sub-01_run-02_bold_mcf.nii -plots
# 181204-04:31:08,155 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.mcflirt
#                        * preproc.segment
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:32:02,970 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mcflirt".
# 181204-04:32:04,217 nipype.workflow INFO:
# 	 [Job 37] Completed (preproc.mcflirt).
# 181204-04:32:04,232 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.segment
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:32:04,533 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.segment" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment".
# 181204-04:32:04,554 nipype.workflow INFO:
# 	 [Node] Running "segment" ("nipype.interfaces.spm.preprocess.NewSegment")
# 181204-04:32:06,220 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.segment
#                        * preproc.segment
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:02,753 nipype.workflow INFO:
# 	 [Node] Finished "preproc.segment".181204-04:39:02,745 nipype.workflow INFO:
# 	 [Node] Finished "preproc.segment".
#
# 181204-04:39:04,665 nipype.workflow INFO:
# 	 [Job 1] Completed (preproc.segment).
# 181204-04:39:05,226 nipype.workflow INFO:
# 	 [Job 17] Completed (preproc.segment).
# 181204-04:39:05,232 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 5 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:05,889 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/resample".
# 181204-04:39:05,893 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.threshold_WM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/threshold_WM".
# 181204-04:39:06,8 nipype.workflow INFO:
# 	 [Node] Running "threshold_WM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment/c2sub-01_T1.nii -thr 0.5000000000 -bin /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii181204-04:39:06,10 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
#
# 181204-04:39:06,668 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 3 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.threshold_WM
#                        * preproc.resample
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:11,527 nipype.workflow INFO:
# 	 [Node] Finished "preproc.threshold_WM".
# 181204-04:39:12,671 nipype.workflow INFO:
# 	 [Job 4] Completed (preproc.threshold_WM).
# 181204-04:39:12,678 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 4 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:13,212 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/coreg".
# 181204-04:39:13,331 nipype.workflow INFO:
# 	 [Node] Running "coreg" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mcflirt/sub-01_run-04_bold_mcf.nii_mean_reg.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-04_bold_mcf.nii_mean_reg_flirt.nii -omat sub-01_run-04_bold_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:39:14,684 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 3 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.resample
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:18,717 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181204-04:39:20,685 nipype.workflow INFO:
# 	 [Job 2] Completed (preproc.resample).
# 181204-04:39:20,720 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 4 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:20,936 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM".
# 181204-04:39:20,971 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181204-04:39:21,874 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181204-04:39:22,687 nipype.workflow INFO:
# 	 [Job 3] Completed (preproc.mask_GM).
# 181204-04:39:22,694 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:22,922 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/resample".
# 181204-04:39:22,935 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181204-04:39:24,691 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:31,472 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181204-04:39:32,695 nipype.workflow INFO:
# 	 [Job 18] Completed (preproc.resample).
# 181204-04:39:32,705 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:32,873 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM".
# 181204-04:39:32,883 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181204-04:39:33,847 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181204-04:39:34,700 nipype.workflow INFO:
# 	 [Job 19] Completed (preproc.mask_GM).
# 181204-04:39:34,712 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:34,851 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.threshold_WM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/threshold_WM".
# 181204-04:39:34,883 nipype.workflow INFO:
# 	 [Node] Running "threshold_WM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment/c2sub-01_T1.nii -thr 0.5000000000 -bin /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:39:35,650 nipype.workflow INFO:
# 	 [Node] Finished "preproc.threshold_WM".
# 181204-04:39:36,703 nipype.workflow INFO:
# 	 [Job 20] Completed (preproc.threshold_WM).
# 181204-04:39:36,708 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:36,966 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/coreg".
# 181204-04:39:36,979 nipype.workflow INFO:
# 	 [Node] Running "coreg" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mcflirt/sub-01_run-03_bold_mcf.nii_mean_reg.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-03_bold_mcf.nii_mean_reg_flirt.nii -omat sub-01_run-03_bold_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:39:38,708 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
#                        * preproc.segment
# 181204-04:39:43,695 nipype.workflow INFO:
# 	 [Node] Finished "preproc.segment".
# 181204-04:39:44,708 nipype.workflow INFO:
# 	 [Job 33] Completed (preproc.segment).
# 181204-04:39:44,714 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:39:44,954 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/resample".
# 181204-04:39:44,985 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181204-04:39:46,713 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:39:54,319 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181204-04:39:54,722 nipype.workflow INFO:
# 	 [Job 34] Completed (preproc.resample).
# 181204-04:39:54,729 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:39:54,869 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM".
# 181204-04:39:54,943 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181204-04:39:55,882 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181204-04:39:56,725 nipype.workflow INFO:
# 	 [Job 35] Completed (preproc.mask_GM).
# 181204-04:39:56,735 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:39:56,909 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.threshold_WM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/threshold_WM".
# 181204-04:39:56,935 nipype.workflow INFO:
# 	 [Node] Running "threshold_WM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment/c2sub-01_T1.nii -thr 0.5000000000 -bin /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:39:57,692 nipype.workflow INFO:
# 	 [Node] Finished "preproc.threshold_WM".
# 181204-04:39:58,726 nipype.workflow INFO:
# 	 [Job 36] Completed (preproc.threshold_WM).
# 181204-04:39:58,732 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:39:58,960 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/coreg".
# 181204-04:39:59,6 nipype.workflow INFO:
# 	 [Node] Running "coreg" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mcflirt/sub-01_run-02_bold_mcf.nii_mean_reg.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-02_bold_mcf.nii_mean_reg_flirt.nii -omat sub-01_run-02_bold_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:40:00,748 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.segment
# 181204-04:40:30,99 nipype.workflow INFO:
# 	 [Node] Finished "preproc.segment".
# 181204-04:40:30,769 nipype.workflow INFO:
# 	 [Job 49] Completed (preproc.segment).
# 181204-04:40:30,779 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:40:30,948 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/resample".
# 181204-04:40:30,972 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181204-04:40:32,773 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:40:39,751 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181204-04:40:40,781 nipype.workflow INFO:
# 	 [Job 50] Completed (preproc.resample).
# 181204-04:40:40,792 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:40:40,902 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM".
# 181204-04:40:40,925 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181204-04:40:41,892 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181204-04:40:42,783 nipype.workflow INFO:
# 	 [Job 51] Completed (preproc.mask_GM).
# 181204-04:40:42,794 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:40:42,947 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.threshold_WM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/threshold_WM".
# 181204-04:40:43,69 nipype.workflow INFO:
# 	 [Node] Running "threshold_WM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c2sub-01_T1.nii -thr 0.5000000000 -bin /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:40:43,981 nipype.workflow INFO:
# 	 [Node] Finished "preproc.threshold_WM".
# 181204-04:40:44,784 nipype.workflow INFO:
# 	 [Job 52] Completed (preproc.threshold_WM).
# 181204-04:40:44,794 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:40:45,18 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mcflirt" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mcflirt".
# 181204-04:40:45,39 nipype.workflow INFO:
# 	 [Node] Running "mcflirt" ("nipype.interfaces.fsl.preprocess.MCFLIRT"), a CommandLine Interface with command:
# mcflirt -in /home/neuro/nipype_tutorial/data/sub-01/func/sub-01_run-01_bold.nii -meanvol -out /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mcflirt/sub-01_run-01_bold_mcf.nii -plots
# 181204-04:40:46,789 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.mcflirt
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:41:37,227 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mcflirt".
# 181204-04:41:38,842 nipype.workflow INFO:
# 	 [Job 53] Completed (preproc.mcflirt).
# 181204-04:41:38,887 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:41:39,40 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.coreg" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/coreg".
# 181204-04:41:39,83 nipype.workflow INFO:
# 	 [Node] Running "coreg" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mcflirt/sub-01_run-01_bold_mcf.nii_mean_reg.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-01_bold_mcf.nii_mean_reg_flirt.nii -omat sub-01_run-01_bold_mcf.nii_mean_reg_flirt.mat -cost bbr -dof 6 -schedule /usr/share/fsl/5.0/etc/flirtsch/bbr.sch -wmseg /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/threshold_WM/c2sub-01_T1_thresh.nii
# 181204-04:41:40,846 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:11,689 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg".
# 181204-04:44:13,17 nipype.workflow INFO:
# 	 [Job 6] Completed (preproc.coreg).
# 181204-04:44:13,31 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:13,226 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.applywarp" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/applywarp".
# 181204-04:44:13,258 nipype.workflow INFO:
# 	 [Node] Running "applywarp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mcflirt/sub-01_run-04_bold_mcf.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-04_bold_mcf_flirt.nii -omat sub-01_run-04_bold_mcf_flirt.mat -applyisoxfm 4.000000 -init /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/coreg/sub-01_run-04_bold_mcf.nii_mean_reg_flirt.mat -interp spline
# 181204-04:44:15,21 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.applywarp
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:30,446 nipype.workflow INFO:
# 	 [Node] Finished "preproc.applywarp".
# 181204-04:44:31,35 nipype.workflow INFO:
# 	 [Job 7] Completed (preproc.applywarp).
# 181204-04:44:31,53 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.coreg
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:31,139 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg".
# 181204-04:44:31,248 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/smooth".
# 181204-04:44:31,276 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 181204-04:44:33,36 nipype.workflow INFO:
# 	 [Job 22] Completed (preproc.coreg).
# 181204-04:44:33,42 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:33,145 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/smooth".
# 181204-04:44:33,167 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 181204-04:44:35,40 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.coreg
#                        * preproc.coreg
# 181204-04:44:42,505 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg".
# 181204-04:44:43,46 nipype.workflow INFO:
# 	 [Job 38] Completed (preproc.coreg).
# 181204-04:44:43,60 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:44:43,196 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.applywarp" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/applywarp".
# 181204-04:44:43,216 nipype.workflow INFO:
# 	 [Node] Running "applywarp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mcflirt/sub-01_run-03_bold_mcf.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-03_bold_mcf_flirt.nii -omat sub-01_run-03_bold_mcf_flirt.mat -applyisoxfm 4.000000 -init /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/coreg/sub-01_run-03_bold_mcf.nii_mean_reg_flirt.mat -interp spline
# 181204-04:44:45,50 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.applywarp
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:44:56,759 nipype.workflow INFO:
# 	 [Node] Finished "preproc.applywarp".
# 181204-04:44:57,61 nipype.workflow INFO:
# 	 [Job 23] Completed (preproc.applywarp).
# 181204-04:44:57,73 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:44:57,204 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/smooth".
# 181204-04:44:57,236 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 181204-04:44:59,66 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:45:29,157 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:45:29,277 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:45:31,96 nipype.workflow INFO:
# 	 [Job 8] Completed (preproc.smooth).
# 181204-04:45:31,98 nipype.workflow INFO:
# 	 [Job 12] Completed (preproc.smooth).
# 181204-04:45:31,113 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:45:31,238 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func".181204-04:45:31,248 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func".
#
# 181204-04:45:31,324 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".181204-04:45:31,324 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
#
# 181204-04:45:31,384 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-04_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-04_bold_mcf_flirt_masked.nii181204-04:45:31,390 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-04_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-04_bold_mcf_flirt_masked.nii
#
# 181204-04:45:31,926 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:45:31,935 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:45:32,75 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:45:32,85 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:45:33,97 nipype.workflow INFO:
# 	 [Job 9] Completed (preproc.mask_func).
# 181204-04:45:33,100 nipype.workflow INFO:
# 	 [Job 13] Completed (preproc.mask_func).
# 181204-04:45:33,110 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 4 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:45:33,222 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/detrend".181204-04:45:33,236 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/detrend".
#
# 181204-04:45:33,254 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:45:33,254 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:45:35,101 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:45:35,964 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:45:37,101 nipype.workflow INFO:
# 	 [Job 24] Completed (preproc.smooth).
# 181204-04:45:37,107 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.coreg
# 181204-04:45:37,357 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func".
# 181204-04:45:37,403 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".
# 181204-04:45:37,442 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-03_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-03_bold_mcf_flirt_masked.nii
# 181204-04:45:38,58 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:45:38,68 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:45:39,101 nipype.workflow INFO:
# 	 [Job 25] Completed (preproc.mask_func).
# 181204-04:45:39,107 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 3 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.coreg
# 181204-04:45:39,267 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/detrend".
# 181204-04:45:39,490 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:45:41,103 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 2 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.coreg
# 181204-04:45:45,862 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:45:46,39 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:45:46,583 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:45:47,109 nipype.workflow INFO:
# 	 [Job 10] Completed (preproc.detrend).
# 181204-04:45:47,111 nipype.workflow INFO:
# 	 [Job 14] Completed (preproc.detrend).
# 181204-04:45:47,114 nipype.workflow INFO:
# 	 [Job 26] Completed (preproc.detrend).
# 181204-04:45:47,120 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 5 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.coreg
# 181204-04:45:47,223 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/datasink".
#
# 181204-04:45:47,246 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181204-04:45:47,235 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/datasink".
# 181204-04:45:47,265 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".181204-04:45:47,257 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/datasink".
# 181204-04:45:47,276 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:45:47,294 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181204-04:45:47,325 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:45:47,327 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:45:49,112 nipype.workflow INFO:
# 	 [Job 11] Completed (preproc.datasink).
# 181204-04:45:49,114 nipype.workflow INFO:
# 	 [Job 15] Completed (preproc.datasink).
# 181204-04:45:49,131 nipype.workflow INFO:
# 	 [Job 27] Completed (preproc.datasink).
# 181204-04:45:49,137 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.coreg
# 181204-04:45:49,236 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/smooth".
# 181204-04:45:49,256 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 181204-04:45:49,280 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.applywarp" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/applywarp".
# 181204-04:45:49,294 nipype.workflow INFO:
# 	 [Node] Running "applywarp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mcflirt/sub-01_run-02_bold_mcf.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-02_bold_mcf_flirt.nii -omat sub-01_run-02_bold_mcf_flirt.mat -applyisoxfm 4.000000 -init /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/coreg/sub-01_run-02_bold_mcf.nii_mean_reg_flirt.mat -interp spline
# 181204-04:45:51,117 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.applywarp
#                        * preproc.smooth
#                        * preproc.coreg
# 181204-04:46:01,402 nipype.workflow INFO:
# 	 [Node] Finished "preproc.coreg".
# 181204-04:46:03,124 nipype.workflow INFO:
# 	 [Job 54] Completed (preproc.coreg).
# 181204-04:46:03,130 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.applywarp
#                        * preproc.smooth
# 181204-04:46:03,243 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.applywarp" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/applywarp".
# 181204-04:46:03,261 nipype.workflow INFO:
# 	 [Node] Running "applywarp" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mcflirt/sub-01_run-01_bold_mcf.nii -ref /home/neuro/nipype_tutorial/data/sub-01/anat/sub-01_T1.nii -out sub-01_run-01_bold_mcf_flirt.nii -omat sub-01_run-01_bold_mcf_flirt.mat -applyisoxfm 4.000000 -init /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/coreg/sub-01_run-01_bold_mcf.nii_mean_reg_flirt.mat -interp spline
# ...
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:35,409 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/detrend".
# 181204-04:46:35,439 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:46:37,162 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 1 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:41,60 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:46:41,169 nipype.workflow INFO:
# 	 [Job 30] Completed (preproc.detrend).
# 181204-04:46:41,176 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 2 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:41,360 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/datasink".
# 181204-04:46:41,402 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:46:41,448 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:46:43,171 nipype.workflow INFO:
# 	 [Job 31] Completed (preproc.datasink).
# 181204-04:46:43,185 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:43,363 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.smooth" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/smooth".
# 181204-04:46:43,376 nipype.workflow INFO:
# 	 [Node] Running "smooth" ("nipype.interfaces.spm.preprocess.Smooth")
# 181204-04:46:45,176 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:49,85 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:46:49,175 nipype.workflow INFO:
# 	 [Job 44] Completed (preproc.smooth).
# 181204-04:46:49,183 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:49,432 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func".
# 181204-04:46:49,478 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
# 181204-04:46:49,513 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-02_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-02_bold_mcf_flirt_masked.nii
# 181204-04:46:50,133 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:46:50,160 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:46:50,387 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:46:51,177 nipype.workflow INFO:
# 	 [Job 40] Completed (preproc.smooth).
# 181204-04:46:51,183 nipype.workflow INFO:
# 	 [Job 45] Completed (preproc.mask_func).
# 181204-04:46:51,198 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:51,322 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func".181204-04:46:51,327 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/detrend".
#
# 181204-04:46:51,369 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:46:51,418 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".
# 181204-04:46:51,457 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-02_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-02_bold_mcf_flirt_masked.nii
# 181204-04:46:52,125 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:46:52,150 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:46:53,178 nipype.workflow INFO:
# 	 [Job 41] Completed (preproc.mask_func).
# 181204-04:46:53,192 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:53,373 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/detrend".
# 181204-04:46:53,411 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:46:55,183 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:57,147 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:46:57,184 nipype.workflow INFO:
# 	 [Job 46] Completed (preproc.detrend).
# 181204-04:46:57,203 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:57,363 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/datasink".
# 181204-04:46:57,394 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:46:57,428 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:46:59,10 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:46:59,187 nipype.workflow INFO:
# 	 [Job 42] Completed (preproc.detrend).
# 181204-04:46:59,191 nipype.workflow INFO:
# 	 [Job 47] Completed (preproc.datasink).
# 181204-04:46:59,203 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:46:59,322 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/datasink".
# 181204-04:46:59,350 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:46:59,380 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:47:01,188 nipype.workflow INFO:
# 	 [Job 43] Completed (preproc.datasink).
# 181204-04:47:01,197 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.smooth
#                        * preproc.smooth
# 181204-04:47:04,665 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:47:05,190 nipype.workflow INFO:
# 	 [Job 56] Completed (preproc.smooth).
# 181204-04:47:05,194 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.smooth
# 181204-04:47:05,312 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func".
# 181204-04:47:05,326 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".
# 181204-04:47:05,341 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-01_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-01_bold_mcf_flirt_masked.nii
# 181204-04:47:05,859 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:47:05,866 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:47:07,192 nipype.workflow INFO:
# 	 [Job 57] Completed (preproc.mask_func).
# 181204-04:47:07,196 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.smooth
# 181204-04:47:07,271 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/detrend".
# 181204-04:47:07,285 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:47:09,198 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 0 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.smooth
# 181204-04:47:11,668 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:47:13,198 nipype.workflow INFO:
# 	 [Job 58] Completed (preproc.detrend).
# 181204-04:47:13,201 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.smooth
# 181204-04:47:13,310 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/datasink".
# 181204-04:47:13,328 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:47:13,351 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:47:15,200 nipype.workflow INFO:
# 	 [Job 59] Completed (preproc.datasink).
# 181204-04:47:15,204 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.smooth
# 181204-04:47:16,280 nipype.workflow INFO:
# 	 [Node] Finished "preproc.smooth".
# 181204-04:47:17,203 nipype.workflow INFO:
# 	 [Job 60] Completed (preproc.smooth).
# 181204-04:47:17,207 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:17,285 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func".
# 181204-04:47:17,295 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
# 181204-04:47:17,302 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-01_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-01_bold_mcf_flirt_masked.nii
# 181204-04:47:17,635 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181204-04:47:17,647 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181204-04:47:19,206 nipype.workflow INFO:
# 	 [Job 61] Completed (preproc.mask_func).
# 181204-04:47:19,214 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:19,287 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/detrend".
# 181204-04:47:19,294 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181204-04:47:21,208 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * preproc.detrend
# 181204-04:47:23,124 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181204-04:47:23,208 nipype.workflow INFO:
# 	 [Job 62] Completed (preproc.detrend).
# 181204-04:47:23,214 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:23,297 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/datasink".
# 181204-04:47:23,308 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:47:23,318 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181204-04:47:25,210 nipype.workflow INFO:
# 	 [Job 63] Completed (preproc.datasink).
# 181204-04:47:25,215 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.

# %% [markdown]
# # Plot Motion Parameters
# Now, let's investigate the motion parameters. How much did the subject move and turn in the scanner?

# %%
import numpy as np
import pylab as plt

par_file = '/home/neuro/nipype_tutorial/output/datasink/preproc/_run_id_run-03_subject_id_sub-01/sub-01_run-03_bold_mcf.nii.par'
par = np.loadtxt(par_file)

fig, axes = plt.subplots(2, 1, figsize=(15, 5))
axes[0].set_ylabel('rotation (radians)')
axes[0].plot(par[0:, :3])
axes[1].plot(par[0:, 3:])
axes[1].set_xlabel('time (TR)')
axes[1].set_ylabel('translation (mm)')
# Out:
# Text(0, 0.5, 'translation (mm)')

# %% [markdown]
# ### Masks and Probability maps
#
# Let's see what all the masks and probability maps look like. For this, we will use `nilearn`'s `plot_anat` function.

# %% [markdown]
# First, let's look at the tissue probability maps.

# %%
from nilearn import image as nli
from nilearn.plotting import plot_epi
anat = './data/sub-01/anat/sub-01_T1.nii'
gm_prob = '/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c1sub-01_T1.nii'
plot_stat_map(
    gm_prob, title='GM prob. map',  cmap=plt.cm.magma,
    threshold=0.5, bg_img=anat, display_mode='z', cut_coords=range(-35, 15, 10), dim=-1);

# %%
wm_prob = '/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c2sub-01_T1.nii'
plot_stat_map(
    wm_prob, title='WM prob. map',  cmap=plt.cm.magma,
    threshold=0.5, bg_img=anat, display_mode='z', cut_coords=range(-35, 15, 10), dim=-1);

# %%
csf_prob = '/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c3sub-01_T1.nii'
plot_stat_map(
    csf_prob, title='CSF prob. map',  cmap=plt.cm.magma,
    threshold=0.5, bg_img=anat, display_mode='z', cut_coords=range(-35, 15, 10), dim=-1);

# %%
mask_GM = '/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii'
plot_stat_map(
    mask_GM, title='dilated GM Mask', cmap=plt.cm.magma,
    threshold=0.5, bg_img=anat, display_mode='z', cut_coords=range(-35, 15, 10), dim=-1);

# %%
mean = nli.mean_img( '/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii')
plot_epi(mean, title='Masked mean image', display_mode='z', cut_coords=range(-40, 21, 15),
         cmap=plt.cm.viridis);

# %% [markdown]
# ### Functional Image transformations
#
# Let's also investigate the transformation that we applied to the functional images.

# %%
mean = nli.mean_img('/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mcflirt/sub-01_run-01_bold_mcf.nii_mean_reg.nii')
plot_epi(mean, title='Motion Corrected mean image', display_mode='z', cut_coords=range(0, 50, 10),
         cmap=plt.cm.viridis);

# %%
mean = nli.mean_img('/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/applywarp/sub-01_run-01_bold_mcf_flirt.nii')
plot_epi(mean, title='Coregistred mean image', display_mode='z', cut_coords=range(0, 50, 10),
         cmap=plt.cm.viridis);

# %% [markdown]
# ********************************************************************

# %% [markdown]
# # 1st-level Analysis using GLM
#
# In this part we will take the preprocessed output from the first part and run for each subject a 1st-level analysis. For this we need to do the following steps:
#
# 1. Extract onset times of stimuli from TVA file
# 2. Specify the model (TR, high pass filter, onset times, etc.)
# 3. Specify contrasts to compute
# 4. Estimate contrasts
#
# **So, let's begin!**

# %% [markdown]
# # Imports
#
# First, we need to import all modules we later want to use.

# %%
# %pylab inline
from os.path import join as opj
from nipype.interfaces.spm import Level1Design, EstimateModel, EstimateContrast
from nipype.algorithms.modelgen import SpecifySPMModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# # Specify Nodes
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = Node(SpecifySPMModel(concatenate_runs=False,
                                 input_units='secs',
                                 output_units='secs',
                                 time_repetition=TR,
                                 high_pass_filter_cutoff=128),
                 name="modelspec")

# Level1Design - Generates an SPM design matrix
level1design = Node(Level1Design(bases={'hrf': {'derivs': [0, 0]}},
                                 timing_units='secs',
                                 interscan_interval=TR,
                                 model_serial_correlations='AR(1)'),
                    name="level1design")

# EstimateModel - estimate the parameters of the model
level1estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level1estimate")

# EstimateContrast - estimates contrasts
level1conest = Node(EstimateContrast(), name="level1conest")

# %% [markdown]
# # Specify GLM contrasts
#
# To do any GLM analysis, we need to also define the contrasts that we want to investigate.

# %%
# Condition names
condition_names = ['B_first', 'R', 'L', 'L-R', 'B', 'B_last']

# Contrasts
contL1= 'R > B'
contL2= 'L > B'
contL3= 'L-R > B'
contL4= 'L > B or R > B'

cont01 = [contL1,    'T', condition_names, [0, 1, 0, 0, -0.5, -0.5]]
cont02 = [contL2,    'T', condition_names, [0, 0, 1, 0, -0.5, -0.5]]
cont03 = [contL2,    'T', condition_names, [0, 0, 0, 1, -0.5, -0.5]]

cont04 = [contL4,    'F', [cont01, cont02]]

contrast_list = [cont01, cont02, cont03, cont04]

# %% [markdown]
# # Specify GLM Model
#
# The next step is now to get information such as stimuli onset, duration and other regressors into the GLM model. For this we need to create a helper function, in our case called ``subjectinfo``.
#
# To recap, let's see what we have in the TSV file for first run for subject 1:

# %%
# !cat {data_dir}sub-01/func/{subject_list[0]}_{run_list[0]}_event.tsv
# Out:
# onset	duration	stimulus
# 0	10	'B_first'
# 10	6	'R'
# 16	6	'L'
# 22	6	'L-R'
# 28	6	'B'
# 34	6	'R'
# 40	6	'L'
# 46	6	'L-R'
# 52	6	'B'
# 58	6	'R'
# 64	6	'L'
# 70	6	'L-R'
# 76	6	'B'
# 82	6	'R'
# 88	6	'L'
# 94	6	'L-R'
# 100	6	'B'
# 106	6	'R'
# 112	6	'L'
# 118	6	'L-R'
# 124	11	'B_last'

# %% [markdown]
# So what we need is the onset and the stimuli type, i.e. **column 0** and **column 2**.

# %% [markdown]
# Now, let us incorporate all this information in the helper function subjectinfo to get the GLM model.
#
# **Note that since the helper function will be defined as a node, all imports and variables should be redefined.**

# %%
def subjectinfo(subject_id, run_id):

    import numpy as np
    import json
    from os.path import join as opj
    from nipype.interfaces.base import Bunch
    
    data_dir = '/home/neuro/nipype_tutorial/data/'
    
    
    condition_names = ['B_first', 'R', 'L', 'L-R', 'B', 'B_last']
    

    logfile_dir = opj(data_dir, subject_id, 'func')

    # Read the TSV file
    filename = opj(logfile_dir,
                   '%s_%s_event.tsv' % (subject_id, run_id))

    # Save relevant information
    trailinfo = np.genfromtxt(filename, delimiter='\t',
                              dtype=None, skip_header=1)
    trailinfo = [[t[0], t[2]] for t in trailinfo]

    # Separate onset of conditions
    onset1 = []
    onset2 = []
    onset3 = []
    onset4 = []
    onset5 = []
    onset6 = []


    for t in trailinfo:
        condition = t[1]
        onset = t[0]*2
        if b"'B_first'" == condition:
            onset1.append(onset)
            
        if b"'R'" == condition:
            onset2.append(onset)
            
        if b"'L'" == condition:
            onset3.append(onset)
            
        if b"'L-R'" == condition:
            onset4.append(onset)
            
        if b"'B'" == condition:
            onset5.append(onset)
            
        if b"'B_last'" == condition:
            onset6.append(onset)


    subjectinfo = [Bunch(conditions=condition_names,
                         onsets=[onset1, onset2, onset3, onset4, onset5, onset6],
                         durations=[[20.0], [12.0], [12.0], [12.0], [12.0], [22.0]],
                         amplitudes=None,
                         tmod=None,
                         pmod=None,
                         regressor_names=None,
                         regressors=None)]


    return subjectinfo  # this output will later be returned to infosource

# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id', 'run_id'],
                               output_names=['subject_info'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# %%
subjectinfo('sub-01', 'run-02')
# Out:
# [Bunch(amplitudes=None,
#        conditions=['B_first', 'R', 'L', 'L-R', 'B', 'B_last'],
#        durations=[[20.0], [12.0], [12.0], [12.0], [12.0], [22.0]],
#        onsets=[[0],
#         [20, 68, 116, 164, 212],
#         [32, 80, 128, 176, 224],
#         [44, 92, 140, 188, 236],
#         [56, 104, 152, 200],
#         [248]],
#        pmod=None,
#        regressor_names=None,
#        regressors=None,
#        tmod=None)]

# %% [markdown]
# # Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'run_id',
                                            'fwhm_id',
                                            'contrasts'],
                                    contrasts=contrast_list),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('run_id', run_list),
                        ('fwhm_id', fwhm)]

gunzip_func = Node(Gunzip(), name='gunzip_func')

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'func': opj(output_dir, 'preproc', '_run_id_{run_id}_subject_id_{subject_id}',
                         '_fwhm_{fwhm_id}', 'detrend.nii.gz'),
# # Here the unpreprocessed data is used for GLM analyis
# template = {'func': opj(data_dir, '{subject_id}', 'func',
#                 '{subject_id}_{run_id}_bold.nii'),             
             'mc_param': opj(output_dir, 'preproc', '_run_id_{run_id}_subject_id_{subject_id}',
                             '{subject_id}_{run_id}_bold_mcf.nii.par')}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', '')]
subjFolders = [('_fwhm_id_%s%s' % (f, sub), '%s_fwhm%s' % (sub, f))
               for f in fwhm
               for sub in subject_list]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = opj(experiment_dir, working_dir)

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                               ('run_id', 'run_id'),
                                               ('fwhm_id', 'fwhm_id')]),
                    (infosource, getsubjectinfo, [('subject_id', 'subject_id'),
                                                 ('run_id', 'run_id')]),
                    (getsubjectinfo, modelspec, [('subject_info',
                                                  'subject_info')]),
                    (infosource, level1conest, [('contrasts', 'contrasts')]),
                    
                    (selectfiles, gunzip_func, [('func', 'in_file')]),
                    (gunzip_func, modelspec, [('out_file', 'functional_runs')]),
                    
                    (selectfiles, modelspec, [('mc_param',
                                               'realignment_parameters')]),
                    (modelspec, level1design, [('session_info',
                                                'session_info')]),
                    (level1design, level1estimate, [('spm_mat_file',
                                                     'spm_mat_file')]),
                    (level1estimate, level1conest, [('spm_mat_file',
                                                     'spm_mat_file'),
                                                    ('beta_images',
                                                     'beta_images'),
                                                    ('residual_image',
                                                     'residual_image')]),
                    (level1conest, datasink, [('spm_mat_file',
                                               '1stLevel.@spm_mat'),
                                              ('spmT_images', '1stLevel.@T'),
                                              ('con_images', '1stLevel.@con'),
                                              ('spmF_images', '1stLevel.@F'),
                                              ('ess_images', '1stLevel.@ess'),
                                              ]),
                    ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1analysis.base_dir, 'l1analysis', 'graph.png'))
# Out:
# 181204-04:47:33,934 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/l1analysis/graph.png (graph2use=colored, simple_form=True).

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='flat', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1analysis.base_dir, 'l1analysis', 'graph_detailed.png'))
# Out:
# 181204-04:47:34,608 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/l1analysis/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the 1st-level analysis workflow. Change ``n_procs`` to the number of jobs/cores you want to use.

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 4})

# !nipypecli crash /home/neuro/nipype_tutorial/crash-20171203-084943-neuro-getsubjectinfo.a0-ff371092-d758-40cb-a8ea-546235f16065.pklz
# Out:
# 181204-04:47:34,647 nipype.workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 181204-04:47:34,858 nipype.workflow INFO:
# 	 Running in parallel.
# 181204-04:47:34,903 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:35,29 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/selectfiles".181204-04:47:35,24 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/getsubjectinfo".181204-04:47:35,29 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/getsubjectinfo".181204-04:47:35,25 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/selectfiles".
#
#
# 181204-04:47:35,59 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")181204-04:47:35,59 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181204-04:47:35,69 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:47:35,75 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
#
# 181204-04:47:35,92 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:47:35,98 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:47:35,126 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:47:35,128 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:47:36,907 nipype.workflow INFO:
# 	 [Job 0] Completed (l1analysis.getsubjectinfo).
# 181204-04:47:36,914 nipype.workflow INFO:
# 	 [Job 1] Completed (l1analysis.selectfiles).
# 181204-04:47:36,917 nipype.workflow INFO:
# 	 [Job 8] Completed (l1analysis.getsubjectinfo).
# 181204-04:47:36,921 nipype.workflow INFO:
# 	 [Job 9] Completed (l1analysis.selectfiles).
# 181204-04:47:36,928 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:37,32 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/gunzip_func".
# 181204-04:47:37,38 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181204-04:47:37,42 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/gunzip_func".181204-04:47:37,45 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/selectfiles".
# 181204-04:47:37,51 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:47:37,41 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/getsubjectinfo".
#
#
# 181204-04:47:37,63 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
#
# 181204-04:47:37,82 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181204-04:47:37,116 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:47:37,170 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:47:37,905 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:47:37,973 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:47:38,907 nipype.workflow INFO:
# 	 [Job 2] Completed (l1analysis.gunzip_func).
# 181204-04:47:38,913 nipype.workflow INFO:
# 	 [Job 10] Completed (l1analysis.gunzip_func).
# 181204-04:47:38,918 nipype.workflow INFO:
# 	 [Job 16] Completed (l1analysis.getsubjectinfo).
# 181204-04:47:38,921 nipype.workflow INFO:
# 	 [Job 17] Completed (l1analysis.selectfiles).
# 181204-04:47:38,928 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:39,18 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/modelspec".
# 181204-04:47:39,27 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/modelspec".181204-04:47:39,34 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/getsubjectinfo".181204-04:47:39,34 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/gunzip_func".181204-04:47:39,31 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
#
#
# 181204-04:47:39,41 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")181204-04:47:39,53 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")181204-04:47:39,51 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:47:39,98 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:47:39,186 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:47:39,204 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:47:39,860 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:47:40,909 nipype.workflow INFO:
# 	 [Job 3] Completed (l1analysis.modelspec).
# 181204-04:47:40,913 nipype.workflow INFO:
# 	 [Job 11] Completed (l1analysis.modelspec).
# 181204-04:47:40,919 nipype.workflow INFO:
# 	 [Job 18] Completed (l1analysis.gunzip_func).
# 181204-04:47:40,922 nipype.workflow INFO:
# 	 [Job 24] Completed (l1analysis.getsubjectinfo).
# 181204-04:47:40,929 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:47:41,43 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1design".
# 181204-04:47:41,79 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/modelspec".
# 181204-04:47:41,74 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1design".181204-04:47:41,75 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:47:41,82 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/selectfiles".
#
# 181204-04:47:41,119 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")181204-04:47:41,127 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")181204-04:47:41,133 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181204-04:47:41,171 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181204-04:47:41,233 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:47:42,908 nipype.workflow INFO:
# 	 [Job 19] Completed (l1analysis.modelspec).
# 181204-04:47:42,910 nipype.workflow INFO:
# 	 [Job 25] Completed (l1analysis.selectfiles).
# 181204-04:47:42,914 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:47:43,126 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1design".181204-04:47:43,128 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/gunzip_func".
#
# 181204-04:47:43,144 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181204-04:47:43,217 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:47:44,347 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:47:44,911 nipype.workflow INFO:
# 	 [Job 26] Completed (l1analysis.gunzip_func).
# 181204-04:47:44,918 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:47:45,116 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/modelspec".
# 181204-04:47:45,144 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181204-04:47:45,278 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:47:46,913 nipype.workflow INFO:
# 	 [Job 27] Completed (l1analysis.modelspec).
# 181204-04:47:46,929 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:47:47,141 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1design".
# 181204-04:47:47,209 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:47:48,922 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:48:00,570 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:48:00,628 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:48:00,927 nipype.workflow INFO:
# 	 [Job 4] Completed (l1analysis.level1design).
# 181204-04:48:00,931 nipype.workflow INFO:
# 	 [Job 12] Completed (l1analysis.level1design).
# 181204-04:48:00,949 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:48:01,86 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1estimate".181204-04:48:01,91 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1estimate".
#
# 181204-04:48:01,123 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181204-04:48:01,132 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181204-04:48:02,930 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:48:03,265 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:48:04,931 nipype.workflow INFO:
# 	 [Job 20] Completed (l1analysis.level1design).
# 181204-04:48:04,941 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181204-04:48:05,116 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1estimate".
# 181204-04:48:05,150 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181204-04:48:06,935 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181204-04:48:07,162 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:48:08,935 nipype.workflow INFO:
# 	 [Job 28] Completed (l1analysis.level1design).
# 181204-04:48:08,955 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181204-04:48:09,117 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1estimate".
# 181204-04:48:09,165 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181204-04:48:10,940 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181204-04:48:31,858 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181204-04:48:32,791 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181204-04:48:32,959 nipype.workflow INFO:
# 	 [Job 21] Completed (l1analysis.level1estimate).
# 181204-04:48:32,962 nipype.workflow INFO:
# 	 [Job 29] Completed (l1analysis.level1estimate).
# 181204-04:48:32,971 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181204-04:48:33,73 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1conest".181204-04:48:33,92 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1conest".
#
# 181204-04:48:33,138 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")181204-04:48:33,148 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
#
# 181204-04:48:33,495 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181204-04:48:33,546 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181204-04:48:34,960 nipype.workflow INFO:
# 	 [Job 5] Completed (l1analysis.level1estimate).
# 181204-04:48:34,963 nipype.workflow INFO:
# 	 [Job 13] Completed (l1analysis.level1estimate).
# 181204-04:48:34,981 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181204-04:48:35,113 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1conest".
# 181204-04:48:35,133 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1conest".
# 181204-04:48:35,178 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181204-04:48:35,212 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181204-04:48:36,965 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181204-04:48:53,748 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:48:54,70 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:48:54,895 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:48:54,981 nipype.workflow INFO:
# 	 [Job 22] Completed (l1analysis.level1conest).
# 181204-04:48:54,986 nipype.workflow INFO:
# 	 [Job 30] Completed (l1analysis.level1conest).
# 181204-04:48:54,990 nipype.workflow INFO:
# 	 [Job 14] Completed (l1analysis.level1conest).
# 181204-04:48:55,2 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 11 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 181204-04:48:55,120 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/datasink".
# 181204-04:48:55,144 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:48:55,152 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/SPM.mat
# 181204-04:48:55,139 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/datasink".181204-04:48:55,157 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0001.nii
#
# 181204-04:48:55,175 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0002.nii181204-04:48:55,174 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181204-04:48:55,188 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/SPM.mat181204-04:48:55,192 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0003.nii181204-04:48:55,189 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/datasink".
#
#
# 181204-04:48:55,205 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0001.nii181204-04:48:55,206 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmF_0004.nii181204-04:48:55,214 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
#
#
# 181204-04:48:55,223 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181204-04:48:55,223 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0002.nii
# 181204-04:48:55,226 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0001.nii
# 181204-04:48:55,232 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/SPM.mat
# 181204-04:48:55,236 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0003.nii181204-04:48:55,239 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0001.nii
#
#
# 181204-04:48:55,243 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0002.nii181204-04:48:55,248 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0002.nii
#
# 181204-04:48:55,247 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmF_0004.nii181204-04:48:55,256 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0003.nii
# 181204-04:48:55,254 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0003.nii181204-04:48:55,259 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0001.nii
#
# 181204-04:48:55,265 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmF_0004.nii181204-04:48:55,267 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/ess_0004.nii
#
# 181204-04:48:55,275 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0001.nii181204-04:48:55,273 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmF_0004.nii
#
#
# 181204-04:48:55,282 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0002.nii181204-04:48:55,282 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0002.nii181204-04:48:55,286 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/ess_0004.nii
#
#
# 181204-04:48:55,294 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0003.nii181204-04:48:55,291 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0003.nii
# 181204-04:48:55,304 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
#
# 181204-04:48:55,308 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/ess_0004.nii181204-04:48:55,311 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/ess_0004.nii
# 181204-04:48:55,318 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmF_0004.nii
#
# 181204-04:48:55,322 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmF_0004.nii181204-04:48:55,324 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/ess_0004.nii
#
# 181204-04:48:55,330 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/ess_0004.nii
# 181204-04:48:55,339 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".181204-04:48:55,348 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
#
# 181204-04:48:56,983 nipype.workflow INFO:
# 	 [Job 6] Completed (l1analysis.level1conest).
# 181204-04:48:56,988 nipype.workflow INFO:
# 	 [Job 15] Completed (l1analysis.datasink).
# 181204-04:48:56,992 nipype.workflow INFO:
# 	 [Job 23] Completed (l1analysis.datasink).
# 181204-04:48:56,996 nipype.workflow INFO:
# 	 [Job 31] Completed (l1analysis.datasink).
# 181204-04:48:57,1 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:48:57,85 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/datasink".
# 181204-04:48:57,97 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/getsubjectinfo".181204-04:48:57,89 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/getsubjectinfo".
#
# 181204-04:48:57,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/selectfiles".
# 181204-04:48:57,100 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181204-04:48:57,112 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")181204-04:48:57,119 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")181204-04:48:57,115 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
#
# 181204-04:48:57,131 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/SPM.mat
# 181204-04:48:57,147 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0001.nii
# 181204-04:48:57,142 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:48:57,156 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0002.nii
# 181204-04:48:57,173 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:48:57,186 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0003.nii
# 181204-04:48:57,184 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:48:57,195 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmF_0004.nii
# 181204-04:48:57,207 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0001.nii
# 181204-04:48:57,219 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0002.nii
# 181204-04:48:57,228 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0003.nii
# 181204-04:48:57,233 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/ess_0004.nii
# 181204-04:48:57,242 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmF_0004.nii
# 181204-04:48:57,255 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/ess_0004.nii
# 181204-04:48:57,276 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181204-04:48:58,986 nipype.workflow INFO:
# 	 [Job 7] Completed (l1analysis.datasink).
# 181204-04:48:58,993 nipype.workflow INFO:
# 	 [Job 32] Completed (l1analysis.getsubjectinfo).
# 181204-04:48:58,998 nipype.workflow INFO:
# 	 [Job 33] Completed (l1analysis.selectfiles).
# 181204-04:48:59,1 nipype.workflow INFO:
# 	 [Job 40] Completed (l1analysis.getsubjectinfo).
# 181204-04:48:59,7 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:48:59,89 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/gunzip_func".
# 181204-04:48:59,92 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/selectfiles".
# 181204-04:48:59,96 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181204-04:48:59,99 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/selectfiles".181204-04:48:59,99 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/getsubjectinfo".
#
# 181204-04:48:59,186 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:48:59,188 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")181204-04:48:59,190 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181204-04:48:59,206 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181204-04:48:59,216 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:48:59,236 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:48:59,963 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:49:00,988 nipype.workflow INFO:
# 	 [Job 34] Completed (l1analysis.gunzip_func).
# 181204-04:49:00,994 nipype.workflow INFO:
# 	 [Job 41] Completed (l1analysis.selectfiles).
# 181204-04:49:00,998 nipype.workflow INFO:
# 	 [Job 48] Completed (l1analysis.getsubjectinfo).
# 181204-04:49:01,3 nipype.workflow INFO:
# 	 [Job 49] Completed (l1analysis.selectfiles).
# 181204-04:49:01,12 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:49:01,105 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/modelspec".181204-04:49:01,108 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/gunzip_func".181204-04:49:01,111 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/gunzip_func".
# 181204-04:49:01,112 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.getsubjectinfo" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/getsubjectinfo".
#
# 181204-04:49:01,128 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181204-04:49:01,129 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 181204-04:49:01,135 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181204-04:49:01,139 nipype.workflow INFO:
# 	 [Node] Running "getsubjectinfo" ("nipype.interfaces.utility.wrappers.Function")
# <string>:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# 181204-04:49:01,179 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.getsubjectinfo".
# 181204-04:49:01,282 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:49:02,631 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:49:02,950 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:49:02,986 nipype.workflow INFO:
# 	 [Job 35] Completed (l1analysis.modelspec).
# 181204-04:49:02,989 nipype.workflow INFO:
# 	 [Job 42] Completed (l1analysis.gunzip_func).
# 181204-04:49:02,992 nipype.workflow INFO:
# 	 [Job 50] Completed (l1analysis.gunzip_func).
# 181204-04:49:02,995 nipype.workflow INFO:
# 	 [Job 56] Completed (l1analysis.getsubjectinfo).
# 181204-04:49:03,0 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:49:03,113 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/level1design".
# 181204-04:49:03,123 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/modelspec".181204-04:49:03,131 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/modelspec".181204-04:49:03,132 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/selectfiles".
#
#
# 181204-04:49:03,152 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181204-04:49:03,169 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:49:03,244 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:49:03,417 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181204-04:49:03,419 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 181204-04:49:03,433 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181204-04:49:03,554 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:49:04,988 nipype.workflow INFO:
# 	 [Job 43] Completed (l1analysis.modelspec).
# 181204-04:49:04,990 nipype.workflow INFO:
# 	 [Job 51] Completed (l1analysis.modelspec).
# 181204-04:49:04,994 nipype.workflow INFO:
# 	 [Job 57] Completed (l1analysis.selectfiles).
# 181204-04:49:04,998 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1design
# 181204-04:49:05,131 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/level1design".
# 181204-04:49:05,164 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")181204-04:49:05,175 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/level1design".
# 181204-04:49:05,175 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/gunzip_func".
# 181204-04:49:05,197 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
#
# 181204-04:49:05,221 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:49:06,993 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.gunzip_func
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:49:11,669 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181204-04:49:12,995 nipype.workflow INFO:
# 	 [Job 58] Completed (l1analysis.gunzip_func).
# 181204-04:49:13,9 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:49:13,134 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/modelspec".
# 181204-04:49:13,149 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181204-04:49:13,281 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181204-04:49:14,996 nipype.workflow INFO:
# 	 [Job 59] Completed (l1analysis.modelspec).
# 181204-04:49:15,4 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:49:15,164 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/level1design".
# 181204-04:49:15,223 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181204-04:49:17,3 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:49:21,34 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:49:23,5 nipype.workflow INFO:
# 	 [Job 36] Completed (l1analysis.level1design).
# 181204-04:49:23,50 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181204-04:49:23,221 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/level1estimate".
# 181204-04:49:23,281 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181204-04:49:23,475 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:49:24,378 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181204-04:49:25,7 nipype.workflow INFO:
# 	 [Job 44] Completed (l1analysis.level1design).
# 181204-04:49:25,11 nipype.workflow INFO:
# 	 [Job 52] Completed (l1analysis.level1design).
# 181204-04:49:25,29 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181204-04:49:25,179 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/level1estimate".181204-04:49:25,174 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/level1estimate".
#
# 181204-04:49:25,220 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")181204-04:49:25,222 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
#
# 181204-04:49:27,10 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181204-04:49:35,575 nipype.workflow INFO:
# ...
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/level1conest".
# 181204-04:50:01,324 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181204-04:50:03,53 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 4.33/5.13, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181204-04:50:11,688 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:50:13,58 nipype.workflow INFO:
# 	 [Job 38] Completed (l1analysis.level1conest).
# 181204-04:50:13,66 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 4.53/5.13, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181204-04:50:13,215 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/datasink".
# 181204-04:50:13,263 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:50:13,269 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/SPM.mat
# 181204-04:50:13,324 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0001.nii
# 181204-04:50:13,360 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0002.nii
# 181204-04:50:13,415 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0003.nii
# 181204-04:50:13,457 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmF_0004.nii
# 181204-04:50:13,499 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0001.nii
# 181204-04:50:13,536 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0002.nii
# 181204-04:50:13,566 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0003.nii
# 181204-04:50:13,624 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/ess_0004.nii
# 181204-04:50:13,653 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmF_0004.nii
# 181204-04:50:13,682 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/ess_0004.nii
# 181204-04:50:13,721 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181204-04:50:15,19 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:50:15,61 nipype.workflow INFO:
# 	 [Job 54] Completed (l1analysis.level1conest).
# 181204-04:50:15,67 nipype.workflow INFO:
# 	 [Job 39] Completed (l1analysis.datasink).
# 181204-04:50:15,82 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 1 jobs ready. Free memory (GB): 4.73/5.13, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181204-04:50:15,211 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/datasink".
# 181204-04:50:15,242 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:50:15,266 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/SPM.mat
# 181204-04:50:15,288 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0001.nii
# 181204-04:50:15,309 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0002.nii
# 181204-04:50:15,333 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0003.nii
# 181204-04:50:15,353 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmF_0004.nii
# 181204-04:50:15,377 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0001.nii
# 181204-04:50:15,410 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0002.nii
# 181204-04:50:15,436 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0003.nii
# 181204-04:50:15,460 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/ess_0004.nii
# 181204-04:50:15,466 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmF_0004.nii
# 181204-04:50:15,491 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/ess_0004.nii
# 181204-04:50:15,522 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181204-04:50:15,629 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:50:17,61 nipype.workflow INFO:
# 	 [Job 46] Completed (l1analysis.level1conest).
# 181204-04:50:17,64 nipype.workflow INFO:
# 	 [Job 55] Completed (l1analysis.datasink).
# 181204-04:50:17,68 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 181204-04:50:17,183 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/datasink".
# 181204-04:50:17,200 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:50:17,212 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/SPM.mat
# 181204-04:50:17,221 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0001.nii
# 181204-04:50:17,238 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0002.nii
# 181204-04:50:17,248 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0003.nii
# 181204-04:50:17,255 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmF_0004.nii
# 181204-04:50:17,268 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0001.nii
# 181204-04:50:17,283 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0002.nii
# 181204-04:50:17,292 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0003.nii
# 181204-04:50:17,304 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/ess_0004.nii
# 181204-04:50:17,312 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmF_0004.nii
# 181204-04:50:17,319 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/ess_0004.nii
# 181204-04:50:17,334 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181204-04:50:19,64 nipype.workflow INFO:
# 	 [Job 47] Completed (l1analysis.datasink).
# 181204-04:50:19,70 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 0 jobs ready. Free memory (GB): 4.93/5.13, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 181204-04:50:19,305 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181204-04:50:21,68 nipype.workflow INFO:
# 	 [Job 62] Completed (l1analysis.level1conest).
# 181204-04:50:21,75 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.
# 181204-04:50:21,161 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/datasink".
# 181204-04:50:21,174 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181204-04:50:21,187 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/SPM.mat
# 181204-04:50:21,194 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0001.nii
# 181204-04:50:21,198 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0002.nii
# 181204-04:50:21,202 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0003.nii
# 181204-04:50:21,207 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmF_0004.nii
# 181204-04:50:21,211 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0001.nii
# 181204-04:50:21,216 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0002.nii
# 181204-04:50:21,221 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0003.nii
# 181204-04:50:21,225 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/ess_0004.nii
# 181204-04:50:21,234 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmF_0004.nii
# 181204-04:50:21,244 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/ess_0004.nii
# 181204-04:50:21,255 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181204-04:50:23,70 nipype.workflow INFO:
# 	 [Job 63] Completed (l1analysis.datasink).
# 181204-04:50:23,78 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 5.13/5.13, Free processors: 4/4.

# %% [markdown]
# ## Inspect output
#
# Let's check the structure of the output folder, to see if we have everything we wanted to save. You should have nine contrast images (``con_*.nii`` for T-contrasts and ``ess_*.nii`` for T-contrasts) and nine statistic images (``spmT_*.nii`` and ``spmF_*.nii``) for every subject and smoothing kernel.

# %%
# !tree {output_dir}/1stLevel
# Out:
# /home/neuro/nipype_tutorial/output/datasink/1stLevel
# ├── _fwhm_id_4_run_id_run-01sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-02sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-03sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-04sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-01sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-02sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-03sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# └── _fwhm_id_8_run_id_run-04sub-01
#     ├── con_0001.nii
#     ├── con_0002.nii
#     ├── con_0003.nii
#     ├── ess_0004.nii
#     ├── spmF_0004.nii
#     ├── SPM.mat
#     ├── spmT_0001.nii
#     ├── spmT_0002.nii
#     └── spmT_0003.nii
#
# 8 directories, 72 files

# %% [markdown]
# # Visualize results
#
# Let's look at the contrasts of one subject that we've just computed using the anatomical coregistration.

# %%
from nilearn.plotting import plot_stat_map
anatimg = data_dir+'sub-01/anat/sub-01_T1.nii'
# cut_coords=(-14,-12,-10,-8,-6,-4,-2)
cut_coords=(54,56,58,60,62,64,66)
threshold = 3.0


contrasts_dir = output_dir + '/1stLevel/_fwhm_id_4_run_id_run-04sub-01'
plot_stat_map(
    contrasts_dir+'/spmT_0001.nii', title=contL1,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)

plot_stat_map(
    contrasts_dir+'/spmT_0002.nii', title=contL2,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)

plot_stat_map(
    contrasts_dir+'/spmT_0003.nii', title=contL3,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)


plot_stat_map(
    contrasts_dir+'/spmF_0004.nii', title=contL4,
    bg_img=anatimg, threshold=2*threshold, display_mode='z', cut_coords=cut_coords, dim=-1)

# %%
import matplotlib.pyplot as plt
from nibabel.testing import data_path
import nibabel as nib

filename = opj(data_dir, 'sub-01', 'func', 'sub-01_run-01_bold.nii')
img = nib.load(filename)
print(img.shape)

plt.figure(figsize=(7, 5))
plt.plot(img.dataobj[15, 15, 15, :])
plt.xlabel('Time [TRs]', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
# plt.xlim(0, 150)
plt.subplots_adjust(bottom=.12, top=.95, right=.95, left=.12)

show()
# Out:
# (64, 64, 30, 135)
