# %% [markdown]
# # Preprocessing Workflow
#
# This is meant as a very simple example for a preprocessing workflow. In this workflow we will conduct the following steps:
#
# 1. Motion correction of functional images with FSL's MCFLIRT
# 2. Coregistration of functional images to anatomical images (according to FSL's FEAT pipeline)
# 3. Smoothing of coregistrated functional images with FWHM set to 4mm

# %% [markdown]
# ## Imports
#
# First, let's import all modules we later will be needing.

# %%
from os.path import join as opj
import os
import json
import nipype.interfaces.fsl as fsl
from nipype.interfaces.fsl import MCFLIRT, FLIRT
from nipype.interfaces.spm import Smooth
from nipype.interfaces.utility import IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
from nipype.interfaces.spm import NewSegment
from nipype.interfaces.fsl import FLIRT
from nipype.interfaces.fsl import Threshold
from nipype.algorithms.confounds import TSNR
from nipype.interfaces.fsl import ApplyMask
from nipype.algorithms.misc import Gunzip
from nipype import MapNode

# %% [markdown]
# # Dicom to Nifti conversion

# %%
from nipype.interfaces.dcm2nii import Dcm2nii
converter = Dcm2nii()

# convert anatomical data
converter.inputs.gzip_output = False
converter.inputs.source_dir = './data/sub-01/anat/T1_dcm'
converter.inputs.output_dir = './data/sub-01/anat/'
converter.inputs.protocol_in_filename = False
converter.inputs.source_in_filename = False
converter.inputs.date_in_filename = False
converter.inputs.events_in_filename = False
converter.inputs.id_in_filename = True 
converter.inputs.reorient = False
converter.run()
# Out:
# 181203-21:56:48,656 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181203-21:56:48,657 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:reading preferences file config.ini
# 181203-21:56:48,659 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:Data will be exported to ./data/sub-01/anat/
# 181203-21:56:48,660 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:Validating 176 potential DICOM images.
# 181203-21:56:48,661 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:Found 176 DICOM images.
# 181203-21:56:48,662 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.655975:Converting 176/176  volumes: 1
# 181203-21:56:48,687 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.687124:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0002.0001.2018.11.27.10.49.46.171875.342669378.IMA->psych521visualMotor.nii
# 181203-21:56:48,688 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.687124:For slice timing correction: the slice order is ascending
# 181203-21:56:48,688 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.687124: brightest voxel was 908: data will be saved as 16-bit signed integer.
# 181203-21:56:48,700 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:48.700305:Saving ./data/sub-01/anat/psych521visualMotor.nii

# %%
# rename the ziped file according to your convention
new_file_name = './data/sub-01/anat/sub-01_T1.nii'
old_file_name = './data/sub-01/anat/psych521visualMotor.nii'
os.rename(old_file_name, new_file_name)

# %%
# %matplotlib inline
from nilearn import plotting

filename = './data/sub-01/anat/sub-01_T1.nii'

plotting.plot_anat(filename,
                   display_mode='z',
                   cut_coords = (10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60),
                   title="plot_anat")

# %%
# convert functional runs data
run_list = ['run-01', 'run-02', 'run-03', 'run-04']
for run in run_list:
    converter = Dcm2nii()
    converter.inputs.gzip_output = False
    converter.inputs.source_dir = './data/sub-01/func/'+run+'_bold_dcm'
    converter.inputs.output_dir = './data/sub-01/func/'
    converter.inputs.protocol_in_filename = False
    converter.inputs.source_in_filename = False
    converter.inputs.date_in_filename = False
    converter.inputs.events_in_filename = False
    converter.inputs.id_in_filename = True 
    converter.run() 
    # rename the ziped file according to your convention
    new_file_name = './data/sub-01/func/sub-01_'+run+'_bold.nii'
    old_file_name = './data/sub-01/func/psych521visualMotor.nii'
    os.rename(old_file_name, new_file_name)
# Out:
# 181203-21:56:51,519 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181203-21:56:51,520 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:reading preferences file config.ini
# 181203-21:56:51,521 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:Data will be exported to ./data/sub-01/func/
# 181203-21:56:51,522 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:Validating 135 potential DICOM images.
# 181203-21:56:51,524 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:Found 135 DICOM images.
# 181203-21:56:51,525 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.519052:Converting 135/135  volumes: 135
# 181203-21:56:51,526 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.526171:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0004.0001.2018.11.27.10.49.46.171875.342673976.IMA->psych521visualMotor.nii
# 181203-21:56:51,527 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.526171: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181203-21:56:51,669 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.669269:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	0	-1002.5	67.5	-937.5	135	-870	200	-802.5	267.5	-735	335	-667.5	402.5	-602.5	470	-535	535	-467.5	602.5	-400	670	-335	737.5	-267.5	802.5	-200	870	-132.5	937.5	-67.5
# 181203-21:56:51,673 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.669269:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181203-21:56:51,674 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.669269:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181203-21:56:51,684 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.669269: brightest voxel was 1278: data will be saved as 16-bit signed integer.
# 181203-21:56:51,689 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:51.689320:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181203-21:56:52,59 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181203-21:56:52,60 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:reading preferences file config.ini
# 181203-21:56:52,61 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:Data will be exported to ./data/sub-01/func/
# 181203-21:56:52,63 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:Validating 135 potential DICOM images.
# 181203-21:56:52,64 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:Found 135 DICOM images.
# 181203-21:56:52,65 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.059348:Converting 135/135  volumes: 135
# 181203-21:56:52,65 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.065887:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0008.0001.2018.11.27.10.49.46.171875.342684166.IMA->psych521visualMotor.nii
# 181203-21:56:52,66 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.065887: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181203-21:56:52,206 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.206684:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	0	-1002.5	67.5	-935	135	-870	202.5	-802.5	267.5	-735	335	-667.5	402.5	-602.5	470	-535	535	-467.5	602.5	-400	670	-335	737.5	-267.5	802.5	-200	870	-132.5	937.5	-67.5
# 181203-21:56:52,207 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.206684:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181203-21:56:52,208 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.206684:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181203-21:56:52,209 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.206684: brightest voxel was 1325: data will be saved as 16-bit signed integer.
# 181203-21:56:52,226 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.226651:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181203-21:56:52,599 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181203-21:56:52,601 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:reading preferences file config.ini
# 181203-21:56:52,602 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:Data will be exported to ./data/sub-01/func/
# 181203-21:56:52,602 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:Validating 135 potential DICOM images.
# 181203-21:56:52,604 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:Found 135 DICOM images.
# 181203-21:56:52,605 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.599615:Converting 135/135  volumes: 135
# 181203-21:56:52,606 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.606660:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0006.0001.2018.11.27.10.49.46.171875.342679026.IMA->psych521visualMotor.nii
# 181203-21:56:52,607 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.606660: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181203-21:56:52,608 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.606660:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	0	-1005	65	-937.5	132.5	-870	200	-802.5	267.5	-737.5	335	-670	400	-602.5	467.5	-535	535	-470	602.5	-402.5	667.5	-335	735	-267.5	802.5	-202.5	870	-135	935	-67.5
# 181203-21:56:52,744 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.744133:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181203-21:56:52,745 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.744133:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181203-21:56:52,746 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.744133: brightest voxel was 1365: data will be saved as 16-bit signed integer.
# 181203-21:56:52,763 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:52.763872:Saving ./data/sub-01/func/psych521visualMotor.nii
# 181203-21:56:53,133 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:Chris Rorden's dcm2nii :: 4AUGUST2014 (Debian) 64bit BSD License
# 181203-21:56:53,135 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:reading preferences file config.ini
# 181203-21:56:53,136 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:Data will be exported to ./data/sub-01/func/
# 181203-21:56:53,136 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:Validating 135 potential DICOM images.
# 181203-21:56:53,147 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:Found 135 DICOM images.
# 181203-21:56:53,151 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.133631:Converting 135/135  volumes: 135
# 181203-21:56:53,152 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.152487:PSYCH521_VISUALMOTOR.MR.BOYACI_LAB_COMMON_EXAMS.0010.0001.2018.11.27.10.49.46.171875.342689252.IMA->psych521visualMotor.nii
# 181203-21:56:53,153 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.152487: Warning: Siemens interleaved acquisition with an even number of slices. Assume even slices acquired PRIOR to odd slices. https://wiki.cimec.unitn.it/tiki-index.php?page=MRIBOLDfMRI
# 181203-21:56:53,154 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.152487:  MosaicRefAcqTimes (30 values for Slice Time Correction) 	0	-1005	65	-937.5	132.5	-870	200	-805	267.5	-737.5	332.5	-670	400	-602.5	467.5	-537.5	535	-470	600	-402.5	667.5	-335	735	-270	802.5	-202.5	867.5	-135	935	-67.5
# 181203-21:56:53,279 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.279470:For slice timing correction: the slice order is Siemens-even interleaved ascending (2,4..,1,3...)
# 181203-21:56:53,280 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.279470:Effective echo spacing: 0.499296993ms, BandwidthPerPixelPhaseEncode: 31.29400063
# 181203-21:56:53,281 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.279470: brightest voxel was 1328: data will be saved as 16-bit signed integer.
# 181203-21:56:53,299 nipype.interface INFO:
# 	 stdout 2018-12-03T21:56:53.299201:Saving ./data/sub-01/func/psych521visualMotor.nii

# %%
# %matplotlib inline
from nilearn import image
from nilearn import plotting

filename = './data/sub-01/func/sub-01_run-01_bold.nii'
print(image.load_img(filename).shape)

selected_volume = image.index_img(filename, 0)

count = 0
for img in image.iter_img(filename):
    # img is now an in-memory 3D img
    
    if count%40==0:
        plotting.plot_anat(img,
                           display_mode='z',
                           cut_coords = (10, 15, 20, 25, 30, 35, 40, 45, 50, 55, 60),
                           title="volume %d"%count)
    count += 1
# Out:
# (64, 64, 30, 135)
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/image/resampling.py:510: UserWarning: Casting data from int32 to float32
#   warnings.warn("Casting data from %s to %s" % (data.dtype.name, aux))

# %% [markdown]
# # Experiment parameters
#
# It's always a good idea to specify all parameters that might change between experiments at the beginning of your script.

# %%
data_dir = '/home/neuro/nipype_tutorial/data/'

experiment_dir = '/home/neuro/nipype_tutorial/output/'
output_dir = '/home/neuro/nipype_tutorial/output/datasink'
working_dir = '/home/neuro/nipype_tutorial/output/workingdir'

# list of subject identifiers
subject_list = ['sub-01']


# list of run identifiers
run_list = ['run-01', 'run-02', 'run-03', 'run-04']


# TR of functional images
TR = 2.0

# Smoothing withds used during preprocessing
fwhm = [4, 8]

# %%
# Use the following tissue specification to get a GM and WM probability map
tpm_img ='/opt/spm12-r7219/spm12_mcr/spm12/tpm/TPM.nii'
tissue1 = ((tpm_img, 1), 1, (True,False), (False, False))
tissue2 = ((tpm_img, 2), 1, (True,False), (False, False))
tissue3 = ((tpm_img, 3), 2, (True,False), (False, False))
tissue4 = ((tpm_img, 4), 3, (False,False), (False, False))
tissue5 = ((tpm_img, 5), 4, (False,False), (False, False))
tissue6 = ((tpm_img, 6), 2, (False,False), (False, False))
tissues = [tissue1, tissue2, tissue3, tissue4, tissue5, tissue6]

# %% [markdown]
# ## Specify Nodes for the main workflow
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# MCFLIRT - motion correction
mcflirt = Node(MCFLIRT(mean_vol=True,
                       save_plots=True,
                       output_type='NIFTI'),
               name="mcflirt")

segment = Node(NewSegment(tissues=tissues), name='segment')

# FLIRT - coregister functional images to anatomical images
coreg_step1 = Node(FLIRT(dof=6,
                   cost='bbr',
                   schedule='/usr/share/fsl/5.0/etc/flirtsch/bbr.sch',
                   output_type='NIFTI'),
             name="coreg")


# Threshold - Threshold WM probability image
threshold_WM = Node(Threshold(thresh=0.5,
                              args='-bin',
                              output_type='NIFTI'),
                name="threshold_WM")
# Specify the isometric voxel resolution you want after coregistration
desired_voxel_iso = 4

# Apply coregistration warp to functional images
coreg_step2 = Node(FLIRT(interp='spline',
                       apply_isoxfm=desired_voxel_iso,
                       output_type='NIFTI'),
                 name="applywarp")

# Initiate resample node
resample = Node(FLIRT(apply_isoxfm=desired_voxel_iso,
                      output_type='NIFTI'),
                name="resample")

# Threshold - Threshold GM probability image
mask_GM = Node(Threshold(thresh=0.5,
                         args='-bin -dilF',
                         output_type='NIFTI'),
                name="mask_GM")

# Smooth - image smoothing
smooth = Node(Smooth(), name="smooth")
smooth.iterables = ("fwhm", fwhm)


mask_func = MapNode(ApplyMask(output_type='NIFTI'),
                    name="mask_func", 
                    iterfield=["in_file"])

detrend = Node(TSNR(regress_poly=2), name="detrend")

# %% [markdown]
# ## Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id', 'run_id']),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('run_id', run_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
anat_file = opj('{subject_id}', 'anat', '{subject_id}_T1.nii')
func_file = opj('{subject_id}', 'func',
                '{subject_id}_{run_id}_bold.nii')

templates = {'anat': anat_file,
             'func': func_file}
selectfiles = Node(SelectFiles(templates,
                               base_directory=data_dir),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Create a preprocessing workflow
preproc = Workflow(name='preproc')
preproc.base_dir = opj(experiment_dir, working_dir)

# Select WM segmentation file from segmentation output
def get_wm(files):
    return files[1][0]

def get_gm(files):
    return files[0][0]

# Connecting the segmentation node with the threshold node
preproc.connect([])

preproc.connect([])

# Connect all components of the preprocessing workflow
preproc.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                            ('run_id', 'run_id')]),
                 (selectfiles, mcflirt, [('func', 'in_file')]),
                 (selectfiles, segment, [('anat', 'channel_files')]),
                 (segment, threshold_WM, [(('native_class_images', get_wm), 'in_file')]),
                 (threshold_WM, coreg_step1, [('out_file', 'wm_seg')]),
                 
                 (mcflirt, coreg_step1, [('mean_img', 'in_file')]),
                 (selectfiles, coreg_step1, [('anat', 'reference')]),

                 (mcflirt, coreg_step2, [('out_file', 'in_file')]),
                 (selectfiles, coreg_step2, [('anat', 'reference')]),
                 (coreg_step1, coreg_step2, [('out_matrix_file',
                                              'in_matrix_file')]),

                 (segment, resample, [(('native_class_images', get_gm), 'in_file'),
                                      (('native_class_images', get_gm), 'reference')
                                      ]),
                 (resample, mask_GM, [('out_file', 'in_file')]),
                 
                 (coreg_step2, smooth, [('out_file', 'in_files')]),
                 (smooth, mask_func, [('smoothed_files', 'in_file')]),
                 (mask_GM, mask_func, [('out_file', 'mask_file')]),
                 (mask_func, detrend, [('out_file', 'in_file')]),

                 (mcflirt, datasink, [('par_file', 'preproc.@par')]),
                 (selectfiles, datasink, [('anat', 'preproc.@resample')]),
                 (coreg_step1, datasink, [('out_file', 'preproc.@coregmean')]),
                 (smooth, datasink, [('smoothed_files', 'preproc.@smooth')]),
                 (detrend, datasink, [('detrended_file', 'preproc.@detrend')]),
                 ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create preproc output graph
preproc.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(preproc.base_dir, 'preproc', 'graph.png'))
# Out:
# 181203-23:13:01,831 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/preproc/graph.png (graph2use=colored, simple_form=True).

# %%
# Visualize the detailed graph
preproc.write_graph(graph2use='flat', format='png', simple_form=True)
Image(filename=opj(preproc.base_dir, 'preproc', 'graph_detailed.png'))
# Out:
# 181203-23:13:03,637 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/preproc/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the preprocessing workflow. Change ``n_procs`` to the number of jobs/cores you want to use. **Note** that if  you're using a Docker container and FLIRT fails to run without any good reason, you might need to change memory settings in the Docker preferences (6 GB should be enough for this workflow).

# %%
preproc.run('MultiProc', plugin_args={'n_procs': 4})

# !nipypecli crash /home/neuro/nipype_tutorial/crash-20181202-135706-neuro-selectfiles.b0-54a99b2b-c1f7-47e5-bde8-8f401961f66f.pklz
# Out:
# 181203-23:13:16,481 nipype.workflow INFO:
# 	 Workflow preproc settings: ['check', 'execution', 'logging', 'monitoring']
# 181203-23:13:16,606 nipype.workflow INFO:
# 	 Running in parallel.
# 181203-23:13:16,613 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:16,953 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/selectfiles".181203-23:13:16,954 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/selectfiles".
#
# 181203-23:13:16,947 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/selectfiles".
# 181203-23:13:16,965 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181203-23:13:16,947 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/selectfiles".181203-23:13:16,967 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181203-23:13:16,976 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181203-23:13:16,970 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181203-23:13:16,986 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
#
# 181203-23:13:16,986 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".181203-23:13:16,996 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
#
# 181203-23:13:17,8 nipype.workflow INFO:
# 	 [Node] Finished "preproc.selectfiles".
# 181203-23:13:18,614 nipype.workflow INFO:
# 	 [Job 0] Completed (preproc.selectfiles).
# 181203-23:13:18,617 nipype.workflow INFO:
# 	 [Job 16] Completed (preproc.selectfiles).
# 181203-23:13:18,620 nipype.workflow INFO:
# 	 [Job 32] Completed (preproc.selectfiles).
# 181203-23:13:18,623 nipype.workflow INFO:
# 	 [Job 48] Completed (preproc.selectfiles).
# 181203-23:13:18,629 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:18,954 nipype.workflow INFO:
# 	 [Job 1] Cached (preproc.segment).
# 181203-23:13:18,958 nipype.workflow INFO:
# 	 [Job 5] Cached (preproc.mcflirt).
# 181203-23:13:18,964 nipype.workflow INFO:
# 	 [Job 17] Cached (preproc.segment).
# 181203-23:13:18,967 nipype.workflow INFO:
# 	 [Job 21] Cached (preproc.mcflirt).
# 181203-23:13:20,936 nipype.workflow INFO:
# 	 [Job 4] Cached (preproc.threshold_WM).
# 181203-23:13:20,937 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/resample".
# 181203-23:13:20,946 nipype.workflow INFO:
# 	 [Job 20] Cached (preproc.threshold_WM).
# 181203-23:13:20,948 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/resample".181203-23:13:20,948 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
#
# 181203-23:13:20,955 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181203-23:13:22,617 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.resample
# 181203-23:13:22,935 nipype.workflow INFO:
# 	 [Job 6] Cached (preproc.coreg).
# 181203-23:13:22,960 nipype.workflow INFO:
# 	 [Job 22] Cached (preproc.coreg).
# 181203-23:13:24,974 nipype.workflow INFO:
# 	 [Job 7] Cached (preproc.applywarp).
# 181203-23:13:24,980 nipype.workflow INFO:
# 	 [Job 23] Cached (preproc.applywarp).
# 181203-23:13:25,72 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181203-23:13:25,126 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181203-23:13:26,619 nipype.workflow INFO:
# 	 [Job 2] Completed (preproc.resample).
# 181203-23:13:26,621 nipype.workflow INFO:
# 	 [Job 18] Completed (preproc.resample).
# 181203-23:13:26,625 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 10 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:26,947 nipype.workflow INFO:
# 	 [Job 8] Cached (preproc.smooth).
# 181203-23:13:26,947 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM".
# 181203-23:13:26,952 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii181203-23:13:26,954 nipype.workflow INFO:
# 	 [Job 12] Cached (preproc.smooth).
#
# 181203-23:13:26,960 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM".
# 181203-23:13:26,985 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181203-23:13:27,659 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181203-23:13:27,665 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181203-23:13:28,621 nipype.workflow INFO:
# 	 [Job 3] Completed (preproc.mask_GM).
# 181203-23:13:28,624 nipype.workflow INFO:
# 	 [Job 19] Completed (preproc.mask_GM).
# 181203-23:13:28,629 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:28,913 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func".
# 181203-23:13:28,919 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".181203-23:13:28,920 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func".
#
# 181203-23:13:28,925 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-04_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-04_bold_mcf_flirt_masked.nii
# 181203-23:13:28,927 nipype.workflow INFO:
# 	 [Job 24] Cached (preproc.smooth).
# 181203-23:13:28,931 nipype.workflow INFO:
# 	 [Job 28] Cached (preproc.smooth).
# 181203-23:13:28,930 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
# 181203-23:13:28,942 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-04_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-04_bold_mcf_flirt_masked.nii
# 181203-23:13:30,272 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:30,281 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:30,352 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:30,359 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:30,623 nipype.workflow INFO:
# 	 [Job 9] Completed (preproc.mask_func).
# 181203-23:13:30,626 nipype.workflow INFO:
# 	 [Job 13] Completed (preproc.mask_func).
# 181203-23:13:30,630 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 8 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:30,916 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/detrend".
# 181203-23:13:30,919 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/detrend".181203-23:13:30,923 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181203-23:13:30,926 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func".
# 181203-23:13:30,930 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/mask_func".181203-23:13:30,933 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
#
#
# 181203-23:13:30,948 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".181203-23:13:30,950 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".
#
# 181203-23:13:30,976 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-03_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-03_bold_mcf_flirt_masked.nii181203-23:13:30,974 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-03_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-03_bold_mcf_flirt_masked.nii
#
# 181203-23:13:32,625 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * preproc.mask_func
#                        * preproc.mask_func
#                        * preproc.detrend
#                        * preproc.detrend
# 181203-23:13:32,683 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:32,694 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:32,899 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:32,904 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:34,623 nipype.workflow INFO:
# 	 [Job 25] Completed (preproc.mask_func).
# 181203-23:13:34,626 nipype.workflow INFO:
# 	 [Job 29] Completed (preproc.mask_func).
# 181203-23:13:34,629 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
# 181203-23:13:34,992 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/detrend".181203-23:13:34,994 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/detrend".
#
# 181203-23:13:35,7 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181203-23:13:35,10 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181203-23:13:36,494 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:36,500 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:36,625 nipype.workflow INFO:
# 	 [Job 10] Completed (preproc.detrend).
# 181203-23:13:36,631 nipype.workflow INFO:
# 	 [Job 14] Completed (preproc.detrend).
# 181203-23:13:36,641 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 6 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
# 181203-23:13:37,25 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:37,32 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_8/datasink".
# 181203-23:13:37,42 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:37,55 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:13:37,115 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:37,120 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-04_subject_id_sub-01/_fwhm_4/datasink".
# 181203-23:13:37,128 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:37,135 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:13:38,630 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 4 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * preproc.datasink
#                        * preproc.datasink
#                        * preproc.detrend
#                        * preproc.detrend
# 181203-23:13:38,740 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:38,848 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:38,852 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:38,896 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:40,631 nipype.workflow INFO:
# 	 [Job 26] Completed (preproc.detrend).
# 181203-23:13:40,635 nipype.workflow INFO:
# 	 [Job 30] Completed (preproc.detrend).
# 181203-23:13:40,639 nipype.workflow INFO:
# 	 [Job 11] Completed (preproc.datasink).
# 181203-23:13:40,643 nipype.workflow INFO:
# 	 [Job 15] Completed (preproc.datasink).
# 181203-23:13:40,647 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:40,933 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:40,940 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:40,943 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_8/datasink".181203-23:13:40,946 nipype.workflow INFO:
# 	 [Job 33] Cached (preproc.segment).
#
# 181203-23:13:40,950 nipype.workflow INFO:
# 	 [Job 37] Cached (preproc.mcflirt).
# 181203-23:13:40,952 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:40,961 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:13:40,968 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-03_subject_id_sub-01/_fwhm_4/datasink".
# 181203-23:13:40,972 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:40,981 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:13:41,57 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:41,79 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:42,632 nipype.workflow INFO:
# 	 [Job 27] Completed (preproc.datasink).
# 181203-23:13:42,635 nipype.workflow INFO:
# 	 [Job 31] Completed (preproc.datasink).
# 181203-23:13:42,639 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:42,931 nipype.workflow INFO:
# 	 [Job 36] Cached (preproc.threshold_WM).
# 181203-23:13:42,930 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/resample".
# 181203-23:13:42,936 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181203-23:13:42,956 nipype.workflow INFO:
# 	 [Job 49] Cached (preproc.segment).
# 181203-23:13:42,959 nipype.workflow INFO:
# 	 [Job 53] Cached (preproc.mcflirt).
# 181203-23:13:44,634 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * preproc.resample
# 181203-23:13:44,949 nipype.workflow INFO:
# 	 [Job 38] Cached (preproc.coreg).
# 181203-23:13:44,956 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.resample" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/resample".181203-23:13:44,959 nipype.workflow INFO:
# 	 [Job 52] Cached (preproc.threshold_WM).
#
# 181203-23:13:44,964 nipype.workflow INFO:
# 	 [Node] Running "resample" ("nipype.interfaces.fsl.preprocess.FLIRT"), a CommandLine Interface with command:
# flirt -in /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c1sub-01_T1.nii -ref /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/segment/c1sub-01_T1.nii -out c1sub-01_T1_flirt.nii -omat c1sub-01_T1_flirt.mat -applyisoxfm 4.000000
# 181203-23:13:46,636 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * preproc.resample
#                        * preproc.resample
# 181203-23:13:46,729 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181203-23:13:46,958 nipype.workflow INFO:
# 	 [Job 39] Cached (preproc.applywarp).
# 181203-23:13:46,973 nipype.workflow INFO:
# 	 [Job 54] Cached (preproc.coreg).
# 181203-23:13:48,627 nipype.workflow INFO:
# 	 [Node] Finished "preproc.resample".
# 181203-23:13:48,636 nipype.workflow INFO:
# 	 [Job 34] Completed (preproc.resample).
# 181203-23:13:48,638 nipype.workflow INFO:
# 	 [Job 50] Completed (preproc.resample).
# 181203-23:13:48,642 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:48,919 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM".
# 181203-23:13:48,924 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181203-23:13:48,928 nipype.workflow INFO:
# 	 [Job 40] Cached (preproc.smooth).
# 181203-23:13:48,931 nipype.workflow INFO:
# 	 [Job 44] Cached (preproc.smooth).
# 181203-23:13:48,935 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_GM" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM".
# 181203-23:13:48,954 nipype.workflow INFO:
# 	 [Node] Running "mask_GM" ("nipype.interfaces.fsl.maths.Threshold"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/resample/c1sub-01_T1_flirt.nii -thr 0.5000000000 -bin -dilF /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii
# 181203-23:13:49,561 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181203-23:13:49,586 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_GM".
# 181203-23:13:50,639 nipype.workflow INFO:
# 	 [Job 35] Completed (preproc.mask_GM).
# 181203-23:13:50,643 nipype.workflow INFO:
# 	 [Job 51] Completed (preproc.mask_GM).
# 181203-23:13:50,649 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 3 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:50,937 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func".
# 181203-23:13:50,944 nipype.workflow INFO:
# 	 [Job 55] Cached (preproc.applywarp).
# 181203-23:13:50,943 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func".181203-23:13:50,943 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".
# 181203-23:13:50,949 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-02_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-02_bold_mcf_flirt_masked.nii
#
# 181203-23:13:50,964 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
# 181203-23:13:50,981 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-02_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-02_bold_mcf_flirt_masked.nii
# 181203-23:13:51,500 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:51,508 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:51,676 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:51,682 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:52,641 nipype.workflow INFO:
# 	 [Job 41] Completed (preproc.mask_func).
# 181203-23:13:52,644 nipype.workflow INFO:
# 	 [Job 45] Completed (preproc.mask_func).
# 181203-23:13:52,647 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:13:52,920 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/detrend".181203-23:13:52,921 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/detrend".
#
# 181203-23:13:52,926 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")181203-23:13:52,934 nipype.workflow INFO:
# 	 [Job 56] Cached (preproc.smooth).
# 181203-23:13:52,933 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")181203-23:13:52,937 nipype.workflow INFO:
# 	 [Job 60] Cached (preproc.smooth).
#
#
# 181203-23:13:54,642 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * preproc.detrend
#                        * preproc.detrend
# 181203-23:13:54,998 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func".181203-23:13:55,2 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.mask_func" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func".
#
# 181203-23:13:55,9 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0".181203-23:13:55,13 nipype.workflow INFO:
# 	 [Node] Setting-up "_mask_func0" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0".
# 181203-23:13:55,19 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/smooth/ssub-01_run-01_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/mask_func/mapflow/_mask_func0/ssub-01_run-01_bold_mcf_flirt_masked.nii
# 181203-23:13:55,26 nipype.workflow INFO:
# 	 [Node] Running "_mask_func0" ("nipype.interfaces.fsl.maths.ApplyMask"), a CommandLine Interface with command:
# fslmaths /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/smooth/ssub-01_run-01_bold_mcf_flirt.nii -mas /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/mask_GM/c1sub-01_T1_flirt_thresh.nii /home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/mask_func/mapflow/_mask_func0/ssub-01_run-01_bold_mcf_flirt_masked.nii
#
# 181203-23:13:56,245 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:56,271 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:13:56,633 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".
# 181203-23:13:56,638 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:56,643 nipype.workflow INFO:
# 	 [Node] Finished "_mask_func0".181203-23:13:56,651 nipype.workflow INFO:
# 	 [Job 42] Completed (preproc.detrend).
# 181203-23:13:56,653 nipype.workflow INFO:
# 	 [Job 46] Completed (preproc.detrend).
# 181203-23:13:56,656 nipype.workflow INFO:
# 	 [Job 57] Completed (preproc.mask_func).
# 181203-23:13:56,658 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * preproc.mask_func
#
# 181203-23:13:56,662 nipype.workflow INFO:
# 	 [Node] Finished "preproc.mask_func".
# 181203-23:13:56,958 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:13:56,963 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_8/datasink".181203-23:13:56,965 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
#
# 181203-23:13:56,970 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-02_subject_id_sub-01/_fwhm_4/datasink".181203-23:13:56,972 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/detrend".
#
# 181203-23:13:56,977 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")181203-23:13:56,979 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
#
# 181203-23:13:56,983 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".181203-23:13:56,990 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:13:57,6 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181203-23:13:57,109 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:57,115 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:13:58,645 nipype.workflow INFO:
# 	 [Job 61] Completed (preproc.mask_func).
# 181203-23:13:58,647 nipype.workflow INFO:
# 	 [Job 43] Completed (preproc.datasink).
# 181203-23:13:58,649 nipype.workflow INFO:
# 	 [Job 47] Completed (preproc.datasink).
# 181203-23:13:58,652 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * preproc.detrend
# 181203-23:13:58,936 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.detrend" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/detrend".
# 181203-23:13:58,943 nipype.workflow INFO:
# 	 [Node] Running "detrend" ("nipype.algorithms.confounds.TSNR")
# 181203-23:14:00,178 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:14:00,646 nipype.workflow INFO:
# 	 [Job 58] Completed (preproc.detrend).
# 181203-23:14:00,652 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 1 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * preproc.detrend
# 181203-23:14:00,933 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:14:00,937 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_8/datasink".
# 181203-23:14:00,943 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:14:00,952 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:14:02,147 nipype.workflow INFO:
# 	 [Node] Finished "preproc.detrend".
# 181203-23:14:02,337 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:14:02,649 nipype.workflow INFO:
# 	 [Job 62] Completed (preproc.detrend).
# 181203-23:14:02,652 nipype.workflow INFO:
# 	 [Job 59] Completed (preproc.datasink).
# 181203-23:14:02,655 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:14:02,933 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:14:02,938 nipype.workflow INFO:
# 	 [Node] Setting-up "preproc.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/preproc/_run_id_run-01_subject_id_sub-01/_fwhm_4/datasink".
# 181203-23:14:02,941 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "preproc.datasink".
# 181203-23:14:02,948 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:14:03,665 nipype.workflow INFO:
# 	 [Node] Finished "preproc.datasink".
# 181203-23:14:04,649 nipype.workflow INFO:
# 	 [Job 63] Completed (preproc.datasink).
# 181203-23:14:04,653 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.

# %% [markdown]
# # Plot Motion Parameters
# Now, let's investigate the motion parameters. How much did the subject move and turn in the scanner?

# %%
import numpy as np
import pylab as plt

par_file = '/home/neuro/nipype_tutorial/output/datasink/preproc/_run_id_run-03_subject_id_sub-01/sub-01_run-03_bold_mcf.nii.par'
par = np.loadtxt(par_file)

fig, axes = plt.subplots(2, 1, figsize=(15, 5))
axes[0].set_ylabel('rotation (radians)')
axes[0].plot(par[0:, :3])
axes[1].plot(par[0:, 3:])
axes[1].set_xlabel('time (TR)')
axes[1].set_ylabel('translation (mm)')
# Out:
# Text(0, 0.5, 'translation (mm)')

# %% [markdown]
# ********************************************************************

# %% [markdown]
# # 1st-level Analysis using GLM
#
# In this part we will take the preprocessed output from the first part and run for each subject a 1st-level analysis. For this we need to do the following steps:
#
# 1. Extract onset times of stimuli from TVA file
# 2. Specify the model (TR, high pass filter, onset times, etc.)
# 3. Specify contrasts to compute
# 4. Estimate contrasts
#
# **So, let's begin!**

# %% [markdown]
# # Imports
#
# First, we need to import all modules we later want to use.

# %%
# %pylab inline
from os.path import join as opj
from nipype.interfaces.spm import Level1Design, EstimateModel, EstimateContrast
from nipype.algorithms.modelgen import SpecifySPMModel
from nipype.interfaces.utility import Function, IdentityInterface
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.pipeline.engine import Workflow, Node
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['plt', 'axes', 'plotting']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# # Specify Nodes
#
# Initiate all the different interfaces (represented as nodes) that you want to use in your workflow.

# %%
# SpecifyModel - Generates SPM-specific Model
modelspec = Node(SpecifySPMModel(concatenate_runs=False,
                                 input_units='secs',
                                 output_units='secs',
                                 time_repetition=TR,
                                 high_pass_filter_cutoff=128),
                 name="modelspec")

# Level1Design - Generates an SPM design matrix
level1design = Node(Level1Design(bases={'hrf': {'derivs': [0, 0]}},
                                 timing_units='secs',
                                 interscan_interval=TR,
                                 model_serial_correlations='AR(1)'),
                    name="level1design")

# EstimateModel - estimate the parameters of the model
level1estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level1estimate")

# EstimateContrast - estimates contrasts
level1conest = Node(EstimateContrast(), name="level1conest")

# %% [markdown]
# # Specify GLM contrasts
#
# To do any GLM analysis, we need to also define the contrasts that we want to investigate.

# %%
# Condition names
condition_names = ['B_first', 'R', 'L', 'L-R', 'B', 'B_last']

# Contrasts
contL1= 'R > B'
contL2= 'L > B'
contL3= 'L-R > B'
contL4= 'L > B or R > B'

cont01 = [contL1,    'T', condition_names, [0, 1, 0, 0, -0.5, -0.5]]
cont02 = [contL2,    'T', condition_names, [0, 0, 1, 0, -0.5, -0.5]]
cont03 = [contL2,    'T', condition_names, [0, 0, 0, 1, -0.5, -0.5]]

cont04 = [contL4,    'F', [cont01, cont02]]

contrast_list = [cont01, cont02, cont03, cont04]

# %% [markdown]
# # Specify GLM Model
#
# The next step is now to get information such as stimuli onset, duration and other regressors into the GLM model. For this we need to create a helper function, in our case called ``subjectinfo``.
#
# To recap, let's see what we have in the TSV file for first run for subject 1:

# %%
# !cat {data_dir}sub-01/func/{subject_list[0]}_{run_list[0]}_event.tsv
# Out:
# onset	duration	stimulus
# 0	10	'B_first'
# 10	6	'R'
# 16	6	'L'
# 22	6	'L-R'
# 28	6	'B'
# 34	6	'R'
# 40	6	'L'
# 46	6	'L-R'
# 52	6	'B'
# 58	6	'R'
# 64	6	'L'
# 70	6	'L-R'
# 76	6	'B'
# 82	6	'R'
# 88	6	'L'
# 94	6	'L-R'
# 100	6	'B'
# 106	6	'R'
# 112	6	'L'
# 118	6	'L-R'
# 124	11	'B_last'

# %% [markdown]
# So what we need is the onset and the stimuli type, i.e. **column 0** and **column 2**.

# %% [markdown]
# Now, let us incorporate all this information in the helper function subjectinfo to get the GLM model.
#
# **Note that since the helper function will be defined as a node, all imports and variables should be redefined.**

# %%
def subjectinfo(subject_id, run_id):

    import numpy as np
    import json
    from os.path import join as opj
    from nipype.interfaces.base import Bunch
    
    data_dir = '/home/neuro/nipype_tutorial/data/'
    
    
    condition_names = ['B_first', 'R', 'L', 'L-R', 'B', 'B_last']
    

    logfile_dir = opj(data_dir, subject_id, 'func')

    # Read the TSV file
    filename = opj(logfile_dir,
                   '%s_%s_event.tsv' % (subject_id, run_id))

    # Save relevant information
    trailinfo = np.genfromtxt(filename, delimiter='\t',
                              dtype=None, skip_header=1)
    trailinfo = [[t[0], t[2]] for t in trailinfo]

    # Separate onset of conditions
    onset1 = []
    onset2 = []
    onset3 = []
    onset4 = []
    onset5 = []
    onset6 = []


    for t in trailinfo:
        condition = t[1]
        onset = t[0]*2
        if b"'B_first'" == condition:
            onset1.append(onset)
            
        if b"'R'" == condition:
            onset2.append(onset)
            
        if b"'L'" == condition:
            onset3.append(onset)
            
        if b"'L-R'" == condition:
            onset4.append(onset)
            
        if b"'B'" == condition:
            onset5.append(onset)
            
        if b"'B_last'" == condition:
            onset6.append(onset)


    subjectinfo = [Bunch(conditions=condition_names,
                         onsets=[onset1, onset2, onset3, onset4, onset5, onset6],
                         durations=[[20.0], [12.0], [12.0], [12.0], [12.0], [22.0]],
                         amplitudes=None,
                         tmod=None,
                         pmod=None,
                         regressor_names=None,
                         regressors=None)]


    return subjectinfo  # this output will later be returned to infosource

# Get Subject Info - get subject specific condition information
getsubjectinfo = Node(Function(input_names=['subject_id', 'run_id'],
                               output_names=['subject_info'],
                               function=subjectinfo),
                      name='getsubjectinfo')

# %%
subjectinfo('sub-01', 'run-02')
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/ipykernel_launcher.py:22: VisibleDeprecationWarning: Reading unicode strings without specifying the encoding argument is deprecated. Set the encoding, use None for the system default.
# [Bunch(amplitudes=None,
#        conditions=['B_first', 'R', 'L', 'L-R', 'B', 'B_last'],
#        durations=[[20.0], [12.0], [12.0], [12.0], [12.0], [22.0]],
#        onsets=[[0],
#         [20, 68, 116, 164, 212],
#         [32, 80, 128, 176, 224],
#         [44, 92, 140, 188, 236],
#         [56, 104, 152, 200],
#         [248]],
#        pmod=None,
#        regressor_names=None,
#        regressors=None,
#        tmod=None)]

# %% [markdown]
# # Specify input & output stream
#
# Specify where the input data can be found & where and how to save the output data.

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['subject_id',
                                            'run_id',
                                            'fwhm_id',
                                            'contrasts'],
                                    contrasts=contrast_list),
                  name="infosource")
infosource.iterables = [('subject_id', subject_list),
                        ('run_id', run_list),
                        ('fwhm_id', fwhm)]

gunzip_func = Node(Gunzip(), name='gunzip_func')

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'func': opj(output_dir, 'preproc', '_run_id_{run_id}_subject_id_{subject_id}',
                         '_fwhm_{fwhm_id}', 'detrend.nii.gz'),
# # Here the unpreprocessed data is used for GLM analyis
# template = {'func': opj(data_dir, '{subject_id}', 'func',
#                 '{subject_id}_{run_id}_bold.nii'),             
             'mc_param': opj(output_dir, 'preproc', '_run_id_{run_id}_subject_id_{subject_id}',
                             '{subject_id}_{run_id}_bold_mcf.nii.par')}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_subject_id_', '')]
subjFolders = [('_fwhm_id_%s%s' % (f, sub), '%s_fwhm%s' % (sub, f))
               for f in fwhm
               for sub in subject_list]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %% [markdown]
# ## Specify Workflow
#
# Create a workflow and connect the interface nodes and the I/O stream to each other.

# %%
# Initiation of the 1st-level analysis workflow
l1analysis = Workflow(name='l1analysis')
l1analysis.base_dir = opj(experiment_dir, working_dir)

# Connect up the 1st-level analysis components
l1analysis.connect([(infosource, selectfiles, [('subject_id', 'subject_id'),
                                               ('run_id', 'run_id'),
                                               ('fwhm_id', 'fwhm_id')]),
                    (infosource, getsubjectinfo, [('subject_id', 'subject_id'),
                                                 ('run_id', 'run_id')]),
                    (getsubjectinfo, modelspec, [('subject_info',
                                                  'subject_info')]),
                    (infosource, level1conest, [('contrasts', 'contrasts')]),
                    
                    (selectfiles, gunzip_func, [('func', 'in_file')]),
                    (gunzip_func, modelspec, [('out_file', 'functional_runs')]),
                    
                    (selectfiles, modelspec, [('mc_param',
                                               'realignment_parameters')]),
                    (modelspec, level1design, [('session_info',
                                                'session_info')]),
                    (level1design, level1estimate, [('spm_mat_file',
                                                     'spm_mat_file')]),
                    (level1estimate, level1conest, [('spm_mat_file',
                                                     'spm_mat_file'),
                                                    ('beta_images',
                                                     'beta_images'),
                                                    ('residual_image',
                                                     'residual_image')]),
                    (level1conest, datasink, [('spm_mat_file',
                                               '1stLevel.@spm_mat'),
                                              ('spmT_images', '1stLevel.@T'),
                                              ('con_images', '1stLevel.@con'),
                                              ('spmF_images', '1stLevel.@F'),
                                              ('ess_images', '1stLevel.@ess'),
                                              ]),
                    ])

# %% [markdown]
# ## Visualize the workflow
#
# It always helps to visualize your workflow.

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1analysis.base_dir, 'l1analysis', 'graph.png'))
# Out:
# 181203-23:26:50,273 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/l1analysis/graph.png (graph2use=colored, simple_form=True).

# %%
# Create 1st-level analysis output graph
l1analysis.write_graph(graph2use='flat', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l1analysis.base_dir, 'l1analysis', 'graph_detailed.png'))
# Out:
# 181203-23:26:51,358 nipype.workflow INFO:
# 	 Generated workflow graph: /home/neuro/nipype_tutorial/output/workingdir/l1analysis/graph.png (graph2use=flat, simple_form=True).

# %% [markdown]
# ##  Run the Workflow
#
# Now that everything is ready, we can run the 1st-level analysis workflow. Change ``n_procs`` to the number of jobs/cores you want to use.

# %%
l1analysis.run('MultiProc', plugin_args={'n_procs': 4})

# !nipypecli crash /home/neuro/nipype_tutorial/crash-20171203-084943-neuro-getsubjectinfo.a0-ff371092-d758-40cb-a8ea-546235f16065.pklz
# Out:
# 181203-23:27:04,634 nipype.workflow INFO:
# 	 Workflow l1analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 181203-23:27:04,741 nipype.workflow INFO:
# 	 Running in parallel.
# 181203-23:27:04,747 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 16 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:05,25 nipype.workflow INFO:
# 	 [Job 0] Cached (l1analysis.getsubjectinfo).
# 181203-23:27:05,87 nipype.workflow INFO:
# 	 [Job 8] Cached (l1analysis.getsubjectinfo).
# 181203-23:27:05,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/selectfiles".181203-23:27:05,98 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/selectfiles".
#
# 181203-23:27:05,129 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181203-23:27:05,127 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181203-23:27:05,147 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".181203-23:27:05,153 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
#
# 181203-23:27:06,748 nipype.workflow INFO:
# 	 [Job 1] Completed (l1analysis.selectfiles).
# 181203-23:27:06,750 nipype.workflow INFO:
# 	 [Job 9] Completed (l1analysis.selectfiles).
# 181203-23:27:06,754 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 14 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:07,77 nipype.workflow INFO:
# 	 [Job 16] Cached (l1analysis.getsubjectinfo).
# 181203-23:27:07,77 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/gunzip_func".181203-23:27:07,78 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/gunzip_func".
#
# 181203-23:27:07,86 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181203-23:27:07,97 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181203-23:27:07,95 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/selectfiles".
#
# 181203-23:27:07,117 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181203-23:27:07,152 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181203-23:27:07,721 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:27:07,779 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:27:08,750 nipype.workflow INFO:
# 	 [Job 2] Completed (l1analysis.gunzip_func).
# 181203-23:27:08,753 nipype.workflow INFO:
# 	 [Job 10] Completed (l1analysis.gunzip_func).
# 181203-23:27:08,756 nipype.workflow INFO:
# 	 [Job 17] Completed (l1analysis.selectfiles).
# 181203-23:27:08,759 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:09,54 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:09,59 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/modelspec".181203-23:27:09,61 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:09,64 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/modelspec".181203-23:27:09,65 nipype.workflow INFO:
# 	 [Job 24] Cached (l1analysis.getsubjectinfo).
#
# 181203-23:27:09,65 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/gunzip_func".181203-23:27:09,68 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
#
# 181203-23:27:09,72 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181203-23:27:09,75 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 181203-23:27:09,91 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:09,118 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181203-23:27:09,215 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".181203-23:27:09,215 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
#
# 181203-23:27:09,774 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:27:10,752 nipype.workflow INFO:
# 	 [Job 3] Completed (l1analysis.modelspec).
# 181203-23:27:10,757 nipype.workflow INFO:
# 	 [Job 11] Completed (l1analysis.modelspec).
# 181203-23:27:10,761 nipype.workflow INFO:
# 	 [Job 18] Completed (l1analysis.gunzip_func).
# 181203-23:27:10,764 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:11,75 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1design".
# 181203-23:27:11,96 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1design".181203-23:27:11,99 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181203-23:27:11,107 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
#
# 181203-23:27:11,115 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/selectfiles".
#
# 181203-23:27:11,110 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/modelspec".181203-23:27:11,122 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")181203-23:27:11,125 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181203-23:27:11,133 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:11,151 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181203-23:27:11,161 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181203-23:27:11,218 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:27:12,752 nipype.workflow INFO:
# 	 [Job 19] Completed (l1analysis.modelspec).
# 181203-23:27:12,754 nipype.workflow INFO:
# 	 [Job 25] Completed (l1analysis.selectfiles).
# 181203-23:27:12,758 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:27:13,88 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1design".181203-23:27:13,92 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/gunzip_func".
#
# 181203-23:27:13,116 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181203-23:27:13,115 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
#
# 181203-23:27:14,286 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:27:14,753 nipype.workflow INFO:
# 	 [Job 26] Completed (l1analysis.gunzip_func).
# 181203-23:27:14,757 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:27:15,312 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:15,315 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/modelspec".
# 181203-23:27:15,321 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:27:15,330 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181203-23:27:15,367 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:27:16,755 nipype.workflow INFO:
# 	 [Job 27] Completed (l1analysis.modelspec).
# 181203-23:27:16,769 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:27:17,97 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1design".
# 181203-23:27:17,132 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181203-23:27:18,756 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:27:26,676 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:27:26,699 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:27:26,763 nipype.workflow INFO:
# 	 [Job 4] Completed (l1analysis.level1design).
# 181203-23:27:26,767 nipype.workflow INFO:
# 	 [Job 12] Completed (l1analysis.level1design).
# 181203-23:27:26,774 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:27:26,773 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:27:27,76 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:27,79 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:27,79 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1estimate".181203-23:27:27,91 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1estimate".
#
# 181203-23:27:27,106 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".181203-23:27:27,102 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
#
# 181203-23:27:27,121 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")181203-23:27:27,124 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
#
# 181203-23:27:27,700 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:27:28,765 nipype.workflow INFO:
# 	 [Job 20] Completed (l1analysis.level1design).
# 181203-23:27:28,767 nipype.workflow INFO:
# 	 [Job 28] Completed (l1analysis.level1design).
# 181203-23:27:28,791 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 10 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181203-23:27:29,143 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:29,147 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:29,147 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1estimate".
# 181203-23:27:29,157 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:29,163 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1estimate".181203-23:27:29,170 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
#
# 181203-23:27:29,193 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:27:29,235 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181203-23:27:30,767 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181203-23:27:40,797 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181203-23:27:40,853 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181203-23:27:42,484 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181203-23:27:42,777 nipype.workflow INFO:
# 	 [Job 5] Completed (l1analysis.level1estimate).
# 181203-23:27:42,779 nipype.workflow INFO:
# 	 [Job 13] Completed (l1analysis.level1estimate).
# 181203-23:27:42,784 nipype.workflow INFO:
# 	 [Job 21] Completed (l1analysis.level1estimate).
# 181203-23:27:42,787 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 11 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1estimate
# 181203-23:27:42,797 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1estimate".
# 181203-23:27:43,71 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
# 181203-23:27:43,76 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/level1conest".
# 181203-23:27:43,81 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
# 181203-23:27:43,81 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".181203-23:27:43,87 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/level1conest".181203-23:27:43,90 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
#
# 181203-23:27:43,93 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
#
# 181203-23:27:43,103 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")181203-23:27:43,103 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/level1conest".
# 181203-23:27:43,118 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
#
# 181203-23:27:43,131 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181203-23:27:43,116 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181203-23:27:44,779 nipype.workflow INFO:
# 	 [Job 29] Completed (l1analysis.level1estimate).
# 181203-23:27:44,785 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 9 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181203-23:27:45,161 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
# 181203-23:27:45,185 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1conest" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/level1conest".
# 181203-23:27:45,214 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1conest".
# 181203-23:27:45,257 nipype.workflow INFO:
# 	 [Node] Running "level1conest" ("nipype.interfaces.spm.model.EstimateContrast")
# 181203-23:27:46,780 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 8 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181203-23:27:53,287 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:27:53,406 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:27:53,733 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:27:54,802 nipype.workflow INFO:
# 	 [Job 6] Completed (l1analysis.level1conest).
# 181203-23:27:54,804 nipype.workflow INFO:
# 	 [Job 14] Completed (l1analysis.level1conest).
# 181203-23:27:54,806 nipype.workflow INFO:
# 	 [Job 22] Completed (l1analysis.level1conest).
# 181203-23:27:54,809 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 11 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 181203-23:27:55,105 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:27:55,115 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:27:55,121 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-04_subject_id_sub-01/datasink".181203-23:27:55,124 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
#
# 181203-23:27:55,131 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".181203-23:27:55,111 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-04_subject_id_sub-01/datasink".
# 181203-23:27:55,136 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-03_subject_id_sub-01/datasink".181203-23:27:55,142 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:27:55,145 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
#
# 181203-23:27:55,154 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181203-23:27:55,162 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/SPM.mat181203-23:27:55,164 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/SPM.mat
#
# 181203-23:27:55,171 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:27:55,183 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:27:55,189 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/SPM.mat
# 181203-23:27:55,253 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0001.nii
# 181203-23:27:55,265 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0001.nii
# 181203-23:27:55,285 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0001.nii
# 181203-23:27:55,307 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0002.nii
# 181203-23:27:55,322 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0002.nii
# 181203-23:27:55,342 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0002.nii
# 181203-23:27:55,364 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmT_0003.nii
# 181203-23:27:55,384 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmT_0003.nii181203-23:27:55,389 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmF_0004.nii
#
# 181203-23:27:55,436 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmT_0003.nii
# 181203-23:27:55,448 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmF_0004.nii181203-23:27:55,437 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0001.nii
#
# 181203-23:27:55,468 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmF_0004.nii
# 181203-23:27:55,505 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0002.nii181203-23:27:55,503 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0001.nii
#
# 181203-23:27:55,526 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0001.nii
# 181203-23:27:55,540 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0002.nii
# 181203-23:27:55,569 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0002.nii
# 181203-23:27:55,579 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/con_0003.nii
# 181203-23:27:55,595 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/ess_0004.nii
# 181203-23:27:55,606 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/con_0003.nii
# 181203-23:27:55,621 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/con_0003.nii
# 181203-23:27:55,628 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/spmF_0004.nii181203-23:27:55,625 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/ess_0004.nii
# 181203-23:27:55,634 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/ess_0004.nii
# 181203-23:27:55,649 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-03sub-01/ess_0004.nii
#
# 181203-23:27:55,671 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".181203-23:27:55,674 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/spmF_0004.nii
#
# 181203-23:27:55,679 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-04sub-01/ess_0004.nii
# 181203-23:27:55,687 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:27:55,719 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:27:55,783 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/spmF_0004.nii
# 181203-23:27:55,787 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-04sub-01/ess_0004.nii
# 181203-23:27:55,796 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:27:56,803 nipype.workflow INFO:
# 	 [Job 30] Completed (l1analysis.level1conest).
# 181203-23:27:56,805 nipype.workflow INFO:
# 	 [Job 7] Completed (l1analysis.datasink).
# 181203-23:27:56,807 nipype.workflow INFO:
# 	 [Job 15] Completed (l1analysis.datasink).
# 181203-23:27:56,809 nipype.workflow INFO:
# 	 [Job 23] Completed (l1analysis.datasink).
# 181203-23:27:56,811 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 9 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:57,95 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:27:57,99 nipype.workflow INFO:
# 	 [Job 32] Cached (l1analysis.getsubjectinfo).
# 181203-23:27:57,99 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-03_subject_id_sub-01/datasink".181203-23:27:57,103 nipype.workflow INFO:
# 	 [Job 40] Cached (l1analysis.getsubjectinfo).
# 181203-23:27:57,103 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/selectfiles".181203-23:27:57,108 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181203-23:27:57,111 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".181203-23:27:57,116 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
#
# 181203-23:27:57,127 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:27:57,131 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/SPM.mat
# 181203-23:27:57,165 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0001.nii
# 181203-23:27:57,185 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0002.nii
# 181203-23:27:57,204 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmT_0003.nii
# 181203-23:27:57,214 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmF_0004.nii
# 181203-23:27:57,224 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0001.nii
# 181203-23:27:57,235 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0002.nii
# 181203-23:27:57,248 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/con_0003.nii
# 181203-23:27:57,266 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/ess_0004.nii
# 181203-23:27:57,276 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/spmF_0004.nii
# 181203-23:27:57,280 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-03sub-01/ess_0004.nii
# 181203-23:27:57,287 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:27:58,805 nipype.workflow INFO:
# 	 [Job 31] Completed (l1analysis.datasink).
# 181203-23:27:58,807 nipype.workflow INFO:
# 	 [Job 33] Completed (l1analysis.selectfiles).
# 181203-23:27:58,810 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 6 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:27:59,89 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/gunzip_func".181203-23:27:59,91 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/selectfiles".181203-23:27:59,93 nipype.workflow INFO:
# 	 [Job 48] Cached (l1analysis.getsubjectinfo).
#
#
# 181203-23:27:59,98 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/selectfiles".181203-23:27:59,98 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181203-23:27:59,104 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".181203-23:27:59,108 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181203-23:27:59,116 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181203-23:27:59,124 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
# 181203-23:27:59,739 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:28:00,807 nipype.workflow INFO:
# 	 [Job 34] Completed (l1analysis.gunzip_func).
# 181203-23:28:00,809 nipype.workflow INFO:
# 	 [Job 41] Completed (l1analysis.selectfiles).
# 181203-23:28:00,811 nipype.workflow INFO:
# 	 [Job 49] Completed (l1analysis.selectfiles).
# 181203-23:28:00,813 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:28:01,94 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:01,99 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/gunzip_func".181203-23:28:01,98 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/gunzip_func".181203-23:28:01,101 nipype.workflow INFO:
# 	 [Job 56] Cached (l1analysis.getsubjectinfo).
#
# 181203-23:28:01,97 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/modelspec".
#
# 181203-23:28:01,110 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".181203-23:28:01,108 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")
#
# 181203-23:28:01,113 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181203-23:28:01,119 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 181203-23:28:01,184 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:28:02,147 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:28:02,395 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:28:02,809 nipype.workflow INFO:
# 	 [Job 35] Completed (l1analysis.modelspec).
# 181203-23:28:02,811 nipype.workflow INFO:
# 	 [Job 42] Completed (l1analysis.gunzip_func).
# 181203-23:28:02,813 nipype.workflow INFO:
# 	 [Job 50] Completed (l1analysis.gunzip_func).
# 181203-23:28:02,815 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:28:03,121 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/level1design".
# 181203-23:28:03,144 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181203-23:28:03,315 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:03,319 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/modelspec".
# 181203-23:28:03,326 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:03,337 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181203-23:28:03,374 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:28:03,409 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:03,415 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/modelspec".181203-23:28:03,416 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.selectfiles" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/selectfiles".
#
# 181203-23:28:03,426 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:03,434 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181203-23:28:03,441 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
#
# 181203-23:28:03,459 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.selectfiles".
# 181203-23:28:03,521 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:28:04,810 nipype.workflow INFO:
# 	 [Job 43] Completed (l1analysis.modelspec).
# 181203-23:28:04,813 nipype.workflow INFO:
# 	 [Job 51] Completed (l1analysis.modelspec).
# 181203-23:28:04,815 nipype.workflow INFO:
# 	 [Job 57] Completed (l1analysis.selectfiles).
# 181203-23:28:04,820 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 3 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1design
# 181203-23:28:05,125 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/level1design".
# 181203-23:28:05,146 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181203-23:28:05,151 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/level1design".181203-23:28:05,151 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.gunzip_func" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/gunzip_func".
#
# 181203-23:28:05,172 nipype.workflow INFO:
# 	 [Node] Running "gunzip_func" ("nipype.algorithms.misc.Gunzip")181203-23:28:05,180 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
#
# 181203-23:28:06,627 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.gunzip_func".
# 181203-23:28:06,813 nipype.workflow INFO:
# 	 [Job 58] Completed (l1analysis.gunzip_func).
# 181203-23:28:06,817 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:28:07,214 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:07,217 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.modelspec" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/modelspec".
# 181203-23:28:07,262 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.modelspec".
# 181203-23:28:07,290 nipype.workflow INFO:
# 	 [Node] Running "modelspec" ("nipype.algorithms.modelgen.SpecifySPMModel")
# 181203-23:28:07,383 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.modelspec".
# 181203-23:28:08,819 nipype.workflow INFO:
# 	 [Job 59] Completed (l1analysis.modelspec).
# 181203-23:28:08,823 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:28:09,189 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1design" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/level1design".
# 181203-23:28:09,249 nipype.workflow INFO:
# 	 [Node] Running "level1design" ("nipype.interfaces.spm.model.Level1Design")
# 181203-23:28:10,832 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:28:12,794 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:28:12,834 nipype.workflow INFO:
# 	 [Job 36] Completed (l1analysis.level1design).
# 181203-23:28:12,837 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:28:13,210 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:13,223 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/level1estimate".
# 181203-23:28:13,251 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:13,283 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181203-23:28:14,836 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
#                        * l1analysis.level1design
#                        * l1analysis.level1design
# 181203-23:28:15,253 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:28:15,364 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:28:16,837 nipype.workflow INFO:
# 	 [Job 44] Completed (l1analysis.level1design).
# 181203-23:28:16,842 nipype.workflow INFO:
# 	 [Job 52] Completed (l1analysis.level1design).
# 181203-23:28:16,848 nipype.workflow INFO:
# 	 [MultiProc] Running 2 tasks, and 2 jobs ready. Free memory (GB): 6.57/6.97, Free processors: 2/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181203-23:28:17,152 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:17,156 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:17,155 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/level1estimate".181203-23:28:17,163 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/level1estimate".
#
# 181203-23:28:17,168 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:17,188 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")181203-23:28:17,189 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
#
# 181203-23:28:17,222 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181203-23:28:18,840 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1design
# 181203-23:28:19,588 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1design".
# 181203-23:28:20,841 nipype.workflow INFO:
# 	 [Job 60] Completed (l1analysis.level1design).
# 181203-23:28:20,845 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
#                        * l1analysis.level1estimate
# 181203-23:28:21,200 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:21,203 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.level1estimate" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/level1estimate".
# 181203-23:28:21,243 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.level1estimate".
# 181203-23:28:21,291 nipype.workflow INFO:
# 	 [Node] Running "level1estimate" ("nipype.interfaces.spm.model.EstimateModel")
# 181203-23:28:22,844 nipype.workflow INFO:
# 	 [MultiProc] Running 4 tasks, and 0 jobs ready. Free memory (GB): 6.17/6.97, Free processors: 0/4.
#                      Currently running:
#                        * l1analysis.level1estimate
# ...
# 181203-23:28:38,221 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:28:38,881 nipype.workflow INFO:
# 	 [Job 38] Completed (l1analysis.level1conest).
# 181203-23:28:38,893 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 1 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181203-23:28:39,257 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:39,292 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-02_subject_id_sub-01/datasink".
# 181203-23:28:39,340 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:39,371 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:28:39,397 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/SPM.mat
# 181203-23:28:39,472 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0001.nii
# 181203-23:28:39,544 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0002.nii
# 181203-23:28:39,583 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmT_0003.nii
# 181203-23:28:39,619 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmF_0004.nii
# 181203-23:28:39,671 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0001.nii
# 181203-23:28:39,709 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0002.nii
# 181203-23:28:39,753 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/con_0003.nii
# 181203-23:28:39,787 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/ess_0004.nii
# 181203-23:28:39,823 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/spmF_0004.nii
# 181203-23:28:39,847 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-02sub-01/ess_0004.nii
# 181203-23:28:39,876 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:28:40,883 nipype.workflow INFO:
# 	 [Job 39] Completed (l1analysis.datasink).
# 181203-23:28:40,887 nipype.workflow INFO:
# 	 [MultiProc] Running 3 tasks, and 0 jobs ready. Free memory (GB): 6.37/6.97, Free processors: 1/4.
#                      Currently running:
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
#                        * l1analysis.level1conest
# 181203-23:28:43,566 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:28:43,959 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:28:44,885 nipype.workflow INFO:
# 	 [Job 46] Completed (l1analysis.level1conest).
# 181203-23:28:44,887 nipype.workflow INFO:
# 	 [Job 54] Completed (l1analysis.level1conest).
# 181203-23:28:44,890 nipype.workflow INFO:
# 	 [MultiProc] Running 1 tasks, and 2 jobs ready. Free memory (GB): 6.77/6.97, Free processors: 3/4.
#                      Currently running:
#                        * l1analysis.level1conest
# 181203-23:28:45,193 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:45,198 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-02_subject_id_sub-01/datasink".
# 181203-23:28:45,207 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:45,202 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".181203-23:28:45,212 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_8_run_id_run-01_subject_id_sub-01/datasink".
#
# 181203-23:28:45,222 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:45,226 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:28:45,237 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:28:45,240 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/SPM.mat
# 181203-23:28:45,241 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/SPM.mat
# 181203-23:28:45,295 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0001.nii
# 181203-23:28:45,314 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0001.nii
# 181203-23:28:45,341 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0002.nii
# 181203-23:28:45,353 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0002.nii
# 181203-23:28:45,392 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmT_0003.nii
# 181203-23:28:45,402 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmT_0003.nii
# 181203-23:28:45,420 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmF_0004.nii
# 181203-23:28:45,436 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmF_0004.nii
# 181203-23:28:45,456 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0001.nii
# 181203-23:28:45,470 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0001.nii
# 181203-23:28:45,487 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0002.nii
# 181203-23:28:45,509 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0002.nii181203-23:28:45,514 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/con_0003.nii
#
# 181203-23:28:45,525 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/con_0003.nii
# 181203-23:28:45,563 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/ess_0004.nii181203-23:28:45,565 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/ess_0004.nii
#
# 181203-23:28:45,593 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/spmF_0004.nii
# 181203-23:28:45,601 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-02sub-01/ess_0004.nii181203-23:28:45,605 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/spmF_0004.nii
# 181203-23:28:45,611 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_8_run_id_run-01sub-01/ess_0004.nii
#
# 181203-23:28:45,620 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:28:45,620 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:28:45,692 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.level1conest".
# 181203-23:28:46,888 nipype.workflow INFO:
# 	 [Job 62] Completed (l1analysis.level1conest).
# 181203-23:28:46,891 nipype.workflow INFO:
# 	 [Job 47] Completed (l1analysis.datasink).
# 181203-23:28:46,894 nipype.workflow INFO:
# 	 [Job 55] Completed (l1analysis.datasink).
# 181203-23:28:46,897 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 1 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.
# 181203-23:28:47,183 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:47,188 nipype.workflow INFO:
# 	 [Node] Setting-up "l1analysis.datasink" in "/home/neuro/nipype_tutorial/output/workingdir/l1analysis/_fwhm_id_4_run_id_run-01_subject_id_sub-01/datasink".
# 181203-23:28:47,193 nipype.workflow INFO:
# 	 [Node] Outdated cache found for "l1analysis.datasink".
# 181203-23:28:47,203 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181203-23:28:47,208 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/SPM.mat -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/SPM.mat
# 181203-23:28:47,242 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0001.nii
# 181203-23:28:47,266 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0002.nii
# 181203-23:28:47,284 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmT_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmT_0003.nii
# 181203-23:28:47,294 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmF_0004.nii
# 181203-23:28:47,315 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0001.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0001.nii
# 181203-23:28:47,324 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0002.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0002.nii
# 181203-23:28:47,336 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/con_0003.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/con_0003.nii
# 181203-23:28:47,346 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/ess_0004.nii
# 181203-23:28:47,358 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/spmF_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/spmF_0004.nii
# 181203-23:28:47,362 nipype.interface INFO:
# 	 sub: /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01_subject_id_sub-01/ess_0004.nii -> /home/neuro/nipype_tutorial/output/datasink/1stLevel/_fwhm_id_4_run_id_run-01sub-01/ess_0004.nii
# 181203-23:28:47,372 nipype.workflow INFO:
# 	 [Node] Finished "l1analysis.datasink".
# 181203-23:28:48,890 nipype.workflow INFO:
# 	 [Job 63] Completed (l1analysis.datasink).
# 181203-23:28:48,895 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 6.97/6.97, Free processors: 4/4.

# %% [markdown]
# ## Inspect output
#
# Let's check the structure of the output folder, to see if we have everything we wanted to save. You should have nine contrast images (``con_*.nii`` for T-contrasts and ``ess_*.nii`` for T-contrasts) and nine statistic images (``spmT_*.nii`` and ``spmF_*.nii``) for every subject and smoothing kernel.

# %%
# !tree {output_dir}/1stLevel
# Out:
# /home/neuro/nipype_tutorial/output/datasink/1stLevel
# ├── _fwhm_id_4_run_id_run-01sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-02sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-03sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_4_run_id_run-04sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-01sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-02sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# ├── _fwhm_id_8_run_id_run-03sub-01
# │   ├── con_0001.nii
# │   ├── con_0002.nii
# │   ├── con_0003.nii
# │   ├── ess_0004.nii
# │   ├── spmF_0004.nii
# │   ├── SPM.mat
# │   ├── spmT_0001.nii
# │   ├── spmT_0002.nii
# │   └── spmT_0003.nii
# └── _fwhm_id_8_run_id_run-04sub-01
#     ├── con_0001.nii
#     ├── con_0002.nii
#     ├── con_0003.nii
#     ├── ess_0004.nii
#     ├── spmF_0004.nii
#     ├── SPM.mat
#     ├── spmT_0001.nii
#     ├── spmT_0002.nii
#     └── spmT_0003.nii
#
# 8 directories, 72 files

# %% [markdown]
# # Visualize results
#
# Let's look at the contrasts of one subject that we've just computed using the anatomical coregistration.

# %%
from nilearn.plotting import plot_stat_map
anatimg = data_dir+'sub-01/anat/sub-01_T1.nii'
# cut_coords=(-14,-12,-10,-8,-6,-4,-2)
cut_coords=(54,56,58,60,62,64,66)
threshold = 4.0


contrasts_dir = output_dir + '/1stLevel/_fwhm_id_8_run_id_run-04sub-01'
plot_stat_map(
    contrasts_dir+'/spmT_0001.nii', title=contL1,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)

plot_stat_map(
    contrasts_dir+'/spmT_0002.nii', title=contL2,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)

plot_stat_map(
    contrasts_dir+'/spmT_0003.nii', title=contL3,
    bg_img=anatimg, threshold=threshold, display_mode='z', cut_coords=cut_coords, dim=-1)


plot_stat_map(
    contrasts_dir+'/spmF_0004.nii', title=contL4,
    bg_img=anatimg, threshold=2*threshold, display_mode='z', cut_coords=cut_coords, dim=-1)
# Out:
# /opt/miniconda-latest/envs/neuro/lib/python3.6/site-packages/nilearn/plotting/displays.py:767: UserWarning: empty mask
#   get_mask_bounds(new_img_like(img, not_mask, affine))

# %%
import matplotlib.pyplot as plt
from nibabel.testing import data_path
import nibabel as nib

filename = opj(data_dir, 'sub-01', 'func', 'sub-01_run-01_bold.nii')
img = nib.load(filename)
print(img.shape)

plt.figure(figsize=(7, 5))
plt.plot(img.dataobj[15, 15, 15, :])
plt.xlabel('Time [TRs]', fontsize=16)
plt.ylabel('Intensity', fontsize=16)
# plt.xlim(0, 150)
plt.subplots_adjust(bottom=.12, top=.95, right=.95, left=.12)

show()
# Out:
# (64, 64, 30, 135)
